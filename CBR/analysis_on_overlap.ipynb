# %%
import pandas as pd
import joblib 
import numpy as np
import os
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
bad_classes = [
    "prejudicial language",
    "fallacy of slippery slope",
    "slothful induction"
]

# %%
all_predictions = os.listdir('cache/predictions/all')

# %%
all_predictions = [x for x in all_predictions if x.startswith('outputs_dict')]

# %%
data = []
for prediction in all_predictions:
    try:
        outputs_dict = joblib.load('cache/predictions/all/' + prediction)
        if 'meta' in outputs_dict.keys():
            data.append(outputs_dict)
    except Exception as e:
        print(e)
        continue
len(data)
# Out:
# 1060

# %%
subset = []
for x in data:
    if x['meta']['num_cases'] == 6:
        subset.append(x)
len(subset)
# Out:
# 20

# %%
subset[0]
# Out:
# {'note': 'best_hps_final_best_ps',
#  'label_encoder': LabelEncoder(),
#  'meta': {'batch_size': 16,
#   'cbr_threshold': -10000000,
#   'classifier_dropout': 0.8,
#   'data_dir': 'data/new_finegrained',
#   'learning_rate': 3.120210415844665e-05,
#   'num_cases': 6,
#   'num_epochs': 8,
#   'predictions_dir': 'cache/predictions/all',
#   'retrievers': ['simcse'],
#   'weight_decay': 0.07600643653465429,
#   'return_dict': True,
#   'output_hidden_states': False,
#   'output_attentions': False,
#   'torchscript': False,
#   'torch_dtype': None,
#   'use_bfloat16': False,
#   'tf_legacy_loss': False,
#   'pruned_heads': {},
#   'tie_word_embeddings': True,
#   'is_encoder_decoder': False,
#   'is_decoder': False,
#   'cross_attention_hidden_size': None,
#   'add_cross_attention': False,
#   'tie_encoder_decoder': False,
#   'max_length': 20,
#   'min_length': 0,
#   'do_sample': False,
#   'early_stopping': False,
#   'num_beams': 1,
#   'num_beam_groups': 1,
#   'diversity_penalty': 0.0,
#   'temperature': 1.0,
#   'top_k': 50,
#   'top_p': 1.0,
#   'typical_p': 1.0,
#   'repetition_penalty': 1.0,
#   'length_penalty': 1.0,
#   'no_repeat_ngram_size': 0,
#   'encoder_no_repeat_ngram_size': 0,
#   'bad_words_ids': None,
#   'num_return_sequences': 1,
#   'chunk_size_feed_forward': 0,
#   'output_scores': False,
#   'return_dict_in_generate': False,
#   'forced_bos_token_id': None,
#   'forced_eos_token_id': None,
#   'remove_invalid_values': False,
#   'exponential_decay_length_penalty': None,
#   'architectures': ['RobertaForSequenceClassification'],
#   'finetuning_task': None,
#   'id2label': {0: 'LABEL_0',
#    1: 'LABEL_1',
#    2: 'LABEL_2',
#    3: 'LABEL_3',
#    4: 'LABEL_4',
#    5: 'LABEL_5',
#    6: 'LABEL_6',
#    7: 'LABEL_7',
#    8: 'LABEL_8',
#    9: 'LABEL_9',
#    10: 'LABEL_10',
#    11: 'LABEL_11',
#    12: 'LABEL_12'},
#   'label2id': {'LABEL_0': 0,
#    'LABEL_1': 1,
#    'LABEL_2': 2,
#    'LABEL_3': 3,
#    'LABEL_4': 4,
#    'LABEL_5': 5,
#    'LABEL_6': 6,
#    'LABEL_7': 7,
#    'LABEL_8': 8,
#    'LABEL_9': 9,
#    'LABEL_10': 10,
#    'LABEL_11': 11,
#    'LABEL_12': 12},
#   'tokenizer_class': None,
#   'prefix': None,
#   'bos_token_id': 0,
#   'pad_token_id': 1,
#   'eos_token_id': 2,
#   'sep_token_id': None,
#   'decoder_start_token_id': None,
#   'task_specific_params': None,
#   'problem_type': None,
#   'transformers_version': '4.22.1',
#   'gradient_checkpointing': False,
#   'model_type': 'roberta',
#   'vocab_size': 50265,
#   'hidden_size': 768,
#   'num_hidden_layers': 12,
#   'num_attention_heads': 12,
#   'hidden_act': 'gelu',
#   'intermediate_size': 3072,
#   'hidden_dropout_prob': 0.1,
#   'attention_probs_dropout_prob': 0.1,
#   'max_position_embeddings': 514,
#   'type_vocab_size': 1,
#   'initializer_range': 0.02,
#   'layer_norm_eps': 1e-05,
#   'position_embedding_type': 'absolute',
#   'use_cache': True,
#   'output_dir': './cbr_roberta_logical_fallacy_classification',
#   'overwrite_output_dir': False,
#   'do_train': True,
#   'do_eval': True,
#   'do_predict': False,
#   'evaluation_strategy': 'steps',
#   'prediction_loss_only': False,
#   'per_device_train_batch_size': 16,
#   'per_device_eval_batch_size': 16,
#   'per_gpu_train_batch_size': 'None',
#   'per_gpu_eval_batch_size': 'None',
#   'gradient_accumulation_steps': 1,
#   'eval_accumulation_steps': 'None',
#   'eval_delay': 0,
#   'adam_beta1': 0.9,
#   'adam_beta2': 0.999,
#   'adam_epsilon': 1e-08,
#   'max_grad_norm': 1.0,
#   'num_train_epochs': 8,
#   'max_steps': -1,
#   'lr_scheduler_type': 'linear',
#   'warmup_ratio': 0.0,
#   'warmup_steps': 0,
#   'log_level': -1,
#   'log_level_replica': -1,
#   'log_on_each_node': True,
#   'logging_dir': './cbr_roberta_logical_fallacy_classification/runs/Nov18_06-30-52_node01',
#   'logging_strategy': 'steps',
#   'logging_first_step': False,
#   'logging_steps': 200,
#   'logging_nan_inf_filter': True,
#   'save_strategy': 'steps',
#   'save_steps': 500,
#   'save_total_limit': 'None',
#   'save_on_each_node': False,
#   'no_cuda': False,
#   'use_mps_device': False,
#   'seed': 42,
#   'data_seed': 'None',
#   'jit_mode_eval': False,
#   'use_ipex': False,
#   'bf16': False,
#   'fp16': False,
#   'fp16_opt_level': 'O1',
#   'half_precision_backend': 'auto',
#   'bf16_full_eval': False,
#   'fp16_full_eval': False,
#   'tf32': 'None',
#   'local_rank': -1,
#   'xpu_backend': 'None',
#   'tpu_num_cores': 'None',
#   'tpu_metrics_debug': False,
#   'debug': '[]',
#   'dataloader_drop_last': False,
#   'eval_steps': 200,
#   'dataloader_num_workers': 0,
#   'past_index': -1,
#   'run_name': './cbr_roberta_logical_fallacy_classification',
#   'disable_tqdm': False,
#   'remove_unused_columns': True,
#   'label_names': 'None',
#   'load_best_model_at_end': False,
#   'metric_for_best_model': 'None',
#   'greater_is_better': 'None',
#   'ignore_data_skip': False,
#   'sharded_ddp': '[]',
#   'fsdp': '[]',
#   'fsdp_min_num_params': 0,
#   'fsdp_transformer_layer_cls_to_wrap': 'None',
#   'deepspeed': 'None',
#   'label_smoothing_factor': 0.0,
#   'optim': 'adamw_hf',
#   'adafactor': False,
#   'group_by_length': False,
#   'length_column_name': 'length',
#   'report_to': "['wandb']",
#   'ddp_find_unused_parameters': 'None',
#   'ddp_bucket_cap_mb': 'None',
#   'dataloader_pin_memory': True,
#   'skip_memory_metrics': True,
#   'use_legacy_prediction_loop': False,
#   'push_to_hub': False,
#   'resume_from_checkpoint': 'None',
#   'hub_model_id': 'None',
#   'hub_strategy': 'every_save',
#   'hub_token': '<HUB_TOKEN>',
#   'hub_private_repo': False,
#   'include_inputs_for_metrics': False,
#   'fp16_backend': 'auto',
#   'push_to_hub_model_id': 'None',
#   'push_to_hub_organization': 'None',
#   'push_to_hub_token': '<PUSH_TO_HUB_TOKEN>',
#   'mp_parameters': '',
#   'auto_find_batch_size': False,
#   'full_determinism': False,
#   'torchdynamo': 'None',
#   'ray_scope': 'last',
#   'ddp_timeout': 1800,
#   'train_batch_size': 16,
#   'eval_batch_size': 16},
#  'run_name': None,
#  'predictions': {'predictions': array([[-0.51289624, -0.21913919,  0.932785  , ...,  1.2986413 ,
#            6.1447077 , -0.94545126],
#          [ 0.41779512,  0.23502849, -0.8941063 , ..., -0.34044513,
#            7.2263684 , -0.06558827],
#          [-2.1019206 , -1.7234793 , -1.5738244 , ..., -1.0925364 ,
#           -1.1447334 ,  0.97113985],
#          ...,
#          [-0.51924914,  7.835799  , -0.95656365, ..., -0.5187267 ,
#            0.7536705 , -0.79760987],
#          [-0.26804805, -1.7741967 ,  3.4289474 , ..., -0.5559347 ,
#           -0.33831736, -2.0548208 ],
#          [ 0.10517745, -0.5869481 ,  0.2551835 , ..., -0.67461586,
#           -0.22200981, -0.9481626 ]], dtype=float32),
#   'label_ids': array([10, 11,  5,  8,  7,  8,  0,  0,  0,  3,  1,  7,  1,  9,  1,  3,  6,
#           0, 12,  7,  2,  0, 11,  2,  6,  0, 10, 12,  9,  2,  8, 11,  9, 12,
#           9,  9, 12,  7,  2, 12, 12,  4, 11,  9,  0, 10,  1,  3,  6,  1,  9,
#           8,  2,  3, 11,  6,  0, 12,  8,  5, 10,  9,  2,  3,  0,  9,  9,  2,
#           9, 10, 12,  1, 11,  1,  7,  3,  6,  7,  5,  8, 11, 10,  5,  1,  7,
#           7,  1, 11,  0,  7,  0,  0,  6,  5, 11, 10,  9,  8, 11,  5,  0,  2,
#           0,  8,  5,  3,  1,  1,  9,  3,  0,  2, 11,  1, 10,  3,  1,  6,  1,
#           0,  3,  5, 12,  3, 11, 11, 10,  7, 11,  1,  6,  7,  9, 11,  2,  6,
#           0, 11,  3,  5,  2,  0,  8,  2,  5,  9,  6,  1, 12,  0,  6,  9,  7,
#           1,  3,  4,  6, 12,  6, 11,  8,  1,  8,  9, 12,  7, 11,  3, 11, 11,
#          11, 11,  7,  5, 11,  3,  3,  0,  8,  1, 12, 12,  0, 11, 11,  0, 10,
#          11,  0, 10, 11,  7, 12, 11, 11,  1,  5, 11,  6, 11, 11,  9,  9,  2,
#          12, 11,  6,  2, 11,  8,  0,  2,  0, 10,  7,  5,  8,  5,  8,  1,  5,
#           4,  0, 12,  0,  2, 11,  7,  0,  0,  9, 11, 11, 11,  1,  9,  5, 11,
#          11,  2,  8, 10,  1, 11,  9, 11,  8,  8,  0,  8,  0, 11,  9,  0,  3,
#           5, 12,  1, 11,  4, 11,  5, 10,  4,  9, 11, 10,  1,  0,  7, 11, 11,
#           1,  7, 11,  4,  8,  9,  8, 12,  2,  6,  4, 10,  9,  6,  0,  3, 10,
#           9,  0,  2,  3,  6, 11, 11,  3,  5,  3, 11, 11, 11,  7,  1,  1,  7,
#          11,  0,  8, 11,  2, 11,  1,  1, 10, 12,  2, 11,  0,  9,  3,  7, 10,
#          11,  0,  0, 11,  2,  1,  2,  3]),
#   'metrics': {'test_loss': 2.4676921367645264,
#    'test_accuracy': 0.5287009063444109,
#    'test_f1': 0.5311937293171096,
#    'test_precision': 0.5489477330005023,
#    'test_recall': 0.5287009063444109,
#    'test_runtime': 5.5115,
#    'test_samples_per_second': 60.056,
#    'test_steps_per_second': 3.81}},
#  'text': ['You need to go to the party with me, otherwise you’ll just be bored at home.',
#   'If we let this child bring the permission slip late, there is no reason to ever set a deadline for anything again!',
#   'I am committed to preserving traditional marriage, the union of one man and one woman.',
#   '"I believe deeply that canceling the fashion show is the best decision. I know it is. I am very certain about it."',
#   'Most Arabs are Muslims and all the 9/11 hijackers were also Muslims. Therefore most Arabs are hijackers.',
#   'Latin should not be taught in school since it is not spoken anywhere in the world. All learning should have some use to be of value, and a dead language has no practical use.',
#   '"You\'re too ugly to be class president!"',
#   "I don't think we need to talk to the people in the Justice Department about the practicality of enforcing this bill. The Justice Department is full of Democrats, and they are already biased against it.",
#   'Dustin: "Why do you always deflect the argument by insulting me?" Ann: "You\'re ugly and poor!"',
#   "America is the best place to live, because it's better than any other country.",
#   'Everyone is going to get the new smart phone when it comes out this weekend. Why aren’t you?',
#   'surgeons have X-rays to guide them during an operation, lawyers have briefs to guide them during a trial, carpenters have blueprints to guide them when they are building a house. Why, then, shouldn’t students be allowed to look at their textbooks during an examination?',
#   'it is used to promote something based on popularity',
#   'The Soviet Union collapsed after taking up atheism. Therefore, we must avoid atheism for the same reasons.',
#   'More and more people are buying sports utility vehicles. It is time you bought one, too!',
#   'The universe has a beginning. Every thing that has a beginning has a cause. Therefore, the universe has a cause called God.',
#   "If we take away farmers' ability to grow genetically engineered crops, if we eliminate that option, people will go hungry, in fact, people will starve. Unlike my opponent, I choose to use the technology available to us and save lives.",
#   'harmful atheists favor cloning, so cloning is wrong',
#   "You can't prove that space aliens don't exist, so they must be real",
#   '"Men are human. Mary is a human. Therefore, Mary is a man."',
#   'Do the best for your baby',
#   'Of course, your minister says he believes in God.  He would be unemployed otherwise.',
#   'Southerners talk fast. I was just on the phone with one, and I could barely keep up!',
#   'Last year I wanted to quit school because my friends treated me like an outcast and talked about me to my friends. I felt betrayed and sad all of the time but now I think I have a place at my new middle school.',
#   "Senator: I will vote to increase the defense budget. Public: Why don't you care about education?",
#   'Helga: You should not be eating that... it has been scientifically proven that eating fat burgers are no good for your health. Hugh: You eat fat burgers all the time so that can’t be true.',
#   'Unless you can close your eyes to abuse, write a check to save this puppy.',
#   'FlatSam: Common sense tells us that if the earth were a sphere, people on the bottom would fall off. ReasonEric: I don’t think you get to reference something you clearly don’t have.',
#   'Jimmy isn’t at school today. He must be on a family trip.',
#   '"Beware of appeals made only to your feelings and not to your logic."',
#   '"\'What about Red Herring, ma\'am?\'\' "\'I\'m not sure. Is Red Herring a red herring? Or is it the fact that we\'re meant to think Red Herring is a red herring that is actually the red herring?\' "\'Or perhaps the fact you\'re meant to think Red Herring isn\'t a red herring is what makes Red Herring a red herring after all.\' "\'We\'re talking serious metaherrings here.\'" ',
#   '"Everyone wants to be an English teacher."',
#   'Because the last words spoken by either the pilot or co-pilot were "Good night, Malaysia Three-Seven-Zero," the pilot fell asleep and accidentally crashed the plane into the ocean.',
#   'Everyone should be patient and wait for his or her turn in line. However, I need to go to the front because I am late for an appointment.',
#   'The party was going great! Then Gerald showed up and little by little people started collecting their coats and heading home. Gerald ruined the party.',
#   '"Right when I sneezed, the power went off. I must\'ve caused the outage." Bragged Zohaw.',
#   'If you buy the Disney annual pass you will save money when visiting the happiest place on Earth!',
#   '“Guns are like hammers—they’re both tools with metal parts that could be used to kill someone. And yet it would be ridiculous to restrict the purchase of hammers—so restrictions on purchasing guns are equally ridiculous.”',
#   "You've got to donate to the hockey team. They are helping build schools in Uganda. Imagine all of those poor and hungry kids there.",
#   '"If you hadn\'t vandalized that car, don\'t you think things would have gone better for you?"',
#   'Do you think that we should convict this criminal?',
#   'Noisy children are a real headache. Two aspirin will make a headache go away. Therefore, two aspirin will make noisy children go away.',
#   'My first time walking the dog went terribly, so my dog is a terrible one.',
#   " Doug is convinced he has lucky underwear. One time when he forgot to put on his lucky underwear, he got a parking ticket. Doug concludes that because he forgot to wear his lucky underwear, he got the ticket. Doug doesn't wash his lucky underwear often. This part isn't relevant to the example, but it is disturbing nonetheless.",
#   '“But, Dad, I know you had no curfew when you were my age, so how can you give me a curfew?”',
#   'Love America or leave it.',
#   'Mark: Do you believe in virgin births? Sue: You mean that babies are born virgins? Mark: I mean birth without fertilization. Sue: No. Mark: How could you not believe in virgin births? Roughly two billion people believe in them, don’t you think you should reconsider your position?',
#   'The reason billions of children starve to death each year is because we live in a world that does not care.',
#   'The Senator thinks we can solve all our ecological problems by driving a Prius.',
#   'This fallacy assumes something is true (or right, or good) because other people agree with it.',
#   'Every time we sacrifice virgins, it rains. Therefore, sacrificing virgins causes it to rain.',
#   'Mom: (looking at report card) How do you have an F in English?! Son: I don’t know.  Did you see that loaded the dishwasher?  I was about to go mow the lawn.  Need me to do anything else?',
#   'Without this additional insurance, you could find yourself broke and homeless.',
#   'Murder is morally wrong. Therefore, abortion is morally wrong.',
#   'the fault of the wreck is a teenage boy at ECR, so all teenage boys at ECR are bad drivers',
#   "Student tells his professor that he thinks some of Donald Trump's positions have merit. Professor says he can't believe that the student believes in support racism.",
#   'A father tells his son not to start smoking as he will regret it when he is older, and the son points out that his father is a smoker. This does not alter the fact that his son may regret smoking when he is older.',
#   'President Clinton being a moral man, being married and loving his daughter; talking about the Bible; going to church',
#   'When your parent asks you why you have a bad grade in math class, and you answer, "All teachers are the enemy!"',
#   'You should eat more green leafy vegetables, because Ms. Lord says so, and she is an expert on grammar and vocabulary.',
#   'Too much candy can cause cavities. You should avoid eating any candy unless you want cavities.',
#   "The report suggests that 'the rise in violent offending and the explosion in the sales of iPods and other portable media devices is more than coincidental,' and asks, rather provocatively, 'Is There an iCrime Wave?' The report notes that nationally, violent crime fell every year from 1993 to 2004, before rising in 2005 and 2006, just as 'America’s streets filled with millions of people visibly wearing, and being distracted by, expensive electronic gear.'",
#   'Expect More. Pay Less.',
#   "Paranormal activity is real because I've seen a ghost.",
#   "Charlie: Fast food is filled with salt, fat, and added sugars. We need better regulation of the industry. Bob: That my be, but you're such a hypocrite! I saw you devour a Triple-Baconator, super-sized fries, and 64oz of soda yesterday!",
#   'Our soccer team was losing until I bought new shoes. We have not lost a game since I got my lucky shoes!',
#   'P1. A sedentary lifestyle contributes to obesity. P2. People have become more sedentary in the last few decades. C. Therefore, the rise in obesity can be fixed by people getting more exercise.',
#   'Jeannette has an upcoming exam in anatomy and physiology. It will cover the four chapters read and discussed over the last month. Jeannette hasn’t studied. Though there are well over 200 terms she will be expected to remember, Jeannette knows that her memory is great. She will remember the terms just from having heard them mentioned in class. After all, because of her excellent memory, she got through high school without studying. Despite her faith in her memory, her lack of studying results in an F on the exam.',
#   'Billy murdered all those people because I spanked him when he was a child.',
#   '"Either you pass this test, or you fail it." Laughed Sr Malak',
#   'the best money can buy…  (Don’t mention it’s expensive and often needs repair.)',
#   "Everyone who is really into gaming already owns the latest video game. Don't be the only one left out!",
#   'I know four poor families. They are lazy drug addicts. Therefore, all poor people are lazy drug addicts.',
#   'Slavery is accepted by just about everyone in our society, so it’s ethical to keep slaves.',
#   'If one is 16 years old or older, one can drive an automobile in Wisconsin.  I saw  your niece driving through Wausau yesterday.  She must be at least 16.',
#   'You must obey the law, because it’s illegal to break the law.',
#   'We should prohibit all cadets from assisting on emergency services missions. Some cadets are so immature they won’t ever stop goofing around.',
#   'The house is white; therefore it must be big',
#   'We should offer movies on our company’s website. REPLY: No, we’ve built our company’s fortune by renting movies only through our stores.',
#   "My wife wants to talk about cleaning out the garage, so I asked her what she wants to do with our patio furniture. Now she's shopping for new patio furniture and not asking me about the garage.",
#   'Three congressional representatives have had affairs. Therefore, members of Congress are adulterers.',
#   "Either you love bacon, or you're wrong.",
#   'Bill: Hey, did you hear we have a new operating system out now?  It is better than anything else out there because we just released it! Steve: What’s it called? Bill: Windows Vista! Steve: Sounds wonderful!  I can’t wait until all of your users install it on all their computers!',
#   'Everybody know that staying out in the rain can make you sick.',
#   'All Jim Carrey movies are hilarious. No horror movies are Jim Carrey movies. Therefore, no horror movies are hilarious.',
#   "the analogy 'animal Auschwitz,' which compares the treatment of animals to the treatment of Jews, gays and other groups during the Nazi era.",
#   'Cheesecake Factory is the best because it is always crowded',
#   "If you forget to floss, you will get cavities, and if you get cavities, you will lose all your teeth by the time you're 30.",
#   "J: Cats are better than dogs. V: Dogs are better. J: You are a lazy person. You won't even be able to take care of a dog.",
#   'You passed everyone in the class, so I should get extra credit',
#   "You're wrong because you're ugly!",
#   "You are not a credible resource person. You haven't finished college.",
#   'we should not build bike lanes because cyclists run red lights',
#   'Michael Jordan wears Hanes underwear, so you should too!',
#   'Daniel was a precocious child and had a liking for logic. He reasoned that atoms are invisible, and that he was made of atoms and therefore invisible too. Unfortunately, despite his thinky skills, he lost the game of hide and go seek.',
#   "Dad, either you let me go to the party or you're a bad dad.",
#   'David: We have way too much police presence in this city. Pete: What are you going to do about it? David: Vandalize, loot, and perhaps a little arson.',
#   'Warning!  Smoking may cause frostbite?',
#   'Everyone knows that teenagers are lazy',
#   'SM 10: Local talk show host saying we are on the verge of a nuclear war leading to sitting in a basement for months.',
#   "I don't know about you, but I would never take the word of a woman who never finished school.",
#   'Which fallacy am I? Combining facts and evidence with words that stir up emotion, with the attempt to manipulate others into accepting the truth of the argument.',
#   'Bill, you drive a beat-up car from the 1980s. For this reason, we can never allow you to be a lifeguard at the community pool.',
#   'Distracting your audience from the original issue by introducing an irrelevant topic.',
#   'If I made a reference to a monk I would most likely be utilizing...',
#   '"You can\'t give me a D because I\'m an A student!"',
#   "This fast food chain claims that they've served five billion people, so they must have the best hamburger in town. Five billion people can't be wrong!",
#   "See the movie that everybody's talking about",
#   'Our house was burglarized right after that new family moved in next door. Therefore, that new family must have been involved.',
#   'Ralph Nader and Pat Buchanan are banging at the doors, and the political establishment, consisting of both politicians and the media, seems determined not to let them in on the grounds that they have no public support.',
#   'She asserts that we need more military spending, but that is false, since she is only saying it because she is a Republican.',
#   'I believe that when we die, we are all given new, young, perfect bodies, and we spend eternity with those whom we love. I can’t imagine the point of life if it all just ends when we die!',
#   'James, the company you work for just filed for bankruptcy! How can I trust you with our money?',
#   "In this election, we've seen the highest voter turnout ever recorded. If you have any doubts about Tyler Espinoza's qualifications, just look at how many people have come out to vote for him.",
#   'There are two kinds of people in this world: those who like penguins, and those who are terrible monsters.',
#   "Senator Randall isn't lying when she says she cares about her constituents—she wouldn't lie to people she cares about.",
#   '“Everyone else is doing it, so should you”.',
#   "People who don't support the proposed state minimum wage increase hate the poor.",
#   'claiming that an idea or belief is true simply because it is what most people believe',
#   'My opponent in this election claims to have the best interests of our community at heart. However, he is separated from his family. Isn’t family the basic unit of society? How can we entrust the concerns of the community to someone who was not able to keep his family together?',
#   'Smoking pot is against the law because it is wrong; I know it is wrong because it is against the law',
#   'I have no intention of stopping the use of somatostatin on patients suffering from acute pancreatitis. I consider it to be a very reasonable choice. After all, it has been standard practice in our department for many years and we’ve been quite satisfied with the results we’ve had.',
#   'How many school shootings should we tolerate before we change the gun laws?',
#   'I view any discussion concerning the limiting of therapy as morally wrong, that is why I do not accept it.',
#   "Most of my testimony about the defendant was the opposite of what I actually believe but I'll bet there's no expert witness who has always told the truth from the time they were old enough to talk, so I'm no less honest than they are.",
#   '"Some tall people recently vandalized the park, tall people are irresponsible."',
#   'Purchase our product or no one is going to think you’re attractive.',
#   'People who buy stocks are no different from people who bet on horse racing. They both risk their money with little chance of making a big profit.',
#   'I believe one should never deliberately hurt another person, that’s why I can never be a surgeon.',
#   'since EVERYONE else is buying a product, so should you!',
#   'What I object to most about those people who oppose capital punishment is that they believe that the lives of convicted murderers are more important than the lives of the police and prison guards who protect us. But, obviously, since the lives of those who protect us are of the greatest value, no one should oppose capital punishment.',
#   'He has my vote for senator, because he has the best shirts.',
#   'Someone really should move this ‘deer crossing’ sign. This is a dangerous stretch of highway and the deer really should be crossing somewhere else.',
#   'Christine has a terrible experience with a boyfriend. She decides that all boys are mean.',
#   'Timmy: Mom, what if I don’t believe in God? Mom: Then you burn in Hell forever.  Why do you ask? Timmy: No reason.',
#   '"Florida is the most important state because it has sun and beaches."',
#   'Now you tell me she looks presidential, folks. I look presidential',
#   'At a party you overhear a friend tell her spouse, “I had high blood pressure at the doctor’s office today; I really need to reduce the stress in my job.”',
#   'You should drive on the right side of the road because that is what the law says, and the law is the law.',
#   '“We should abolish the death penalty. Many respected people, such as actor Guy Handsome, have publicly stated their opposition to it.”',
#   "I know you don't like the kitty-cat  sweater that Grandma knitted for you, but she worked so hard on it and it will make her happy to see you wear it in the family holiday photo.",
#   "Marco cusses a lot, so you can't listen to a thing he says. He's not a good guy.",
#   "Mrs. Collier, we can't take a quiz tomorrow! The new season of Game of Thrones premieres tonight!!",
#   'an attempt to persuade the reader/audience based on feelings or emotions; emotional response',
#   'Since Dwayne Johnson (aka The Rock) endorsed this protein powder, it must work wonders.',
#   'When sales of hot chocolate go up, street crime drops.',
#   'Person 1: Bicycle infrastructure should be expanded because cycling is a sustainable mode of transportation. Person 2: We should not build bike lanes because cyclists run red lights and endanger pedestrians.',
#   "With 80% of consumers choosing our product, isn't obvious that you should, too?",
#   'Have you stopped cheating on your tests?',
#   'But, Dad, I know you smoked when you were my age, so how can you tell me not to do it?',
#   '"All students everywhere should use clear backpacks because bad things happen at schools where students don\'t use clear backpacks."',
#   'Every time my brother Bill accompanies me to Fenway Park, the Red Sox are sure to lose',
#   "She's wearing red shoes. Her favorite color must be red.",
#   '"Certainly this is the case at most colleges in America nowadays"',
#   'Repeating the same thing as if you’re proving something',
#   'The nuthatch was discovered by Tilly Turnow in the woods, while hopping from branch to branch of an elm tree, singing happily.',
#   "Student: You didn't teach us this; we never learned this. Teacher: So, what you're saying is that you just didn't study it after we went over it in class right? That you don't want to put in the work?",
#   'A recent study found that there are plenty of scientists who disagree with the consensus position on this phenomenon.',
#   'Charlie: I think we should put more money into schools. Quality public education is so important. Bob: So you’re saying we should cut military spending and spend it instead on more spiral notebooks and crayons? I guess you want our country to be a weak, defenseless target for terrorists.',
#   'Duke University has the best basketball player in the NCAA, therefore they will win the tournament this year.',
#   "Roommate A: We need to talk about your dog. He keeps peeing everywhere and making a mess. Roommate B: It's not as big of a problem as your cat. The thing sheds all over my clothes!",
#   'What is the name of the fallacy in question 4 about Marcus?',
#   '"My opponent claims that water pollution is endangering our city waters. But have you thought about all of the air pollution in China? Where they have to wear masks sometimes in the city? That\'s what we really need to worry about."',
#   'One day, Megan wore a Donald Duck t-shirt, and she got an ¨A¨ on her Chemistry test. Now she wears a Donald Duck t-shirt every day to Chemistry class.',
#   'Employer: It says here on your resume that you are a hard worker, you pay attention to detail, and you don’t mind working long hours. Andy: Yes sir. Employer: I spoke to your previous employer.  He says that you constantly change things that should not be changed, you could care less about other people’s privacy, and you had the lowest score in customer relations. Andy: Yes, that is all true, as well. Employer: Great then.  Welcome to our social media team!',
#   '"If my hair looks nice, people will love me."',
#   'No one stops to process...No one appreciates the value',
#   "You can't give me a C! I'm an A student, a C is just wrong!",
#   'This clinic sure makes a lot of money. Each of the psychologists who work there must earn a large income.',
#   'Do most Americans believe in God? To find out, we asked over 10,000 scientists at colleges and universities throughout America. Less than 40 percent said they believed in God. The conclusion is obvious: Most Americans no longer believe in God.',
#   'All sports car drivers are too aggressive!',
#   'Callie: Did you know that Jake Tooten was a racist? Chris: I know Jake well. Why do you say he’s a racist? Callie: He was on a podcast the other day... Chris: Did he say something racist? Callie: No, but the podcast host did an interview two years ago with a woman who said she supported an organization that had a history of racism back in the 1960s. Jake clearly supports racism!',
#   '"Cars cause more deaths than firearms do, so if we ban firearms we should also ban cars."',
#   'An attempt to gain a customer’s trust in an advertisement is referred to as',
#   'A driver with a New York license plate cuts you off in traffic. You decide that all New York drivers are terrible drivers.',
#   '“You can’t give me a C. I’m an A student!”',
#   'The witchcraft problem is the most urgent spiritual crisis in the world today. Why? Because witches threaten our very souls.',
#   '"Don\'t listen to Mr. Fingers when he says walk in the hallways. How can you trust someone who wears bow ties?"',
#   "The city should not be singling out our company's problems at our chemical storage facilities, when the EPA records indicate the city's very own landfill has been cited as needing improvements. The council needs to clean up its own mess, before they go after us.",
#   'Come on! Everyone else thinks the movie is great - you should too!',
#   'Is your stupidity inborn?',
#   'argues that a proposition is true because it has not yet been proven false',
#   'My opponent in this debate wants all of you to increase taxes for a recycling program, but his own company has been fined over a dozen times for pollution and environmental damage.',
#   '"If you don\'t get an A in Mr. K\'s class you will fail high school, never graduate, and end up fighting people for nickels under freeway as a career"',
#   'Teenagers are too immature and self-absorbed to understand anything about global issues.',
#   'No one should believe our dear lady Senator who have had an adulterous relationship.',
#   "Student: You didn't teach us this; we never learned this. Teacher: So, you're either lazy or unwilling to learn is that right?",
#   "My Aunt was in the hospital for 6 weeks because she didn't wear a seatbelt.",
#   "Why would you lend money to some who looks like they don't have a job?",
#   'Either support gun confiscation or have the government provide everyone with his own private nuclear warhead, you decide which one.',
#   "If I don't take this Advanced Placement (A.P.) class, then I won't do well on the exam. If I don't do well on the A.P. exam, then I can't get into a good college. If I can't get into a good college, then I'll never get a good job. If I can't get a good job, then I'm going to have to live in my parents' basement forever. Guess I'll sign up for the A.P. class",
#   'If this client is competent to stand trial, she will certainly know the answers to at least 80% of the questions on this standardized test. She knows the answers to 87% of the test questions. Therefore she is competent to stand trial.',
#   'you are not really an American if you are vegetarian',
#   "If you're going to add that much salt to the soup, you might as well pour the whole box in!",
#   'The child did not do his chores so therefore all children are lazy.',
#   'Aliens must exist because most people believe in them.',
#   'Professor X holds that the use of non-invasive ventilation has no place in the management of ARDS; this, therefore, is the approach we should adopt.',
#   'My parents are vegetarians, and they are good people. Therefore, all vegetarians must be good people.',
#   'Kent: My new car is really fast. Cal: I doubt that it is as fast as a jet fighter so, therefore, it is not fast.',
#   'A person hanging out in a bar will be an alcoholic',
#   '"The Americans I know say they elected the new president because they were tired of having their jobs sent overseas. This question of jobs brought this president into office."',
#   'Dan White ate a lot of Twinkies and then killed the Mayor of San Francisco. If I were a mayor, I’d ban Twinkies so no one would kill me.',
#   'A baseball pitcher bought new socks before he pitched a winning game. The new socks caused a pitcher to throw faster! He will wear the new socks for EVERY game now.',
#   'You should choose to work more overtime at the same rate of pay. After all, you wouldn’t want to lose your job, would you?',
#   'If your neighbor robs a bank, should you go to jail?',
#   'Atheists are morally bankrupt.',
#   'If the argument is supposed to be about whether or not we, as the American public should wear masks, and you argue: "Asking an infant to wear a mask is ridiculous!"',
#   '"If we don\'t adopt that puppy today, they might put him down. Do you want to be responsible for that?" Exclaimed Yasir.',
#   '"All elephants are big. Some boys are big. Therefore some boys are elephants."',
#   'Finish your dinner. There are starving children in Africa.',
#   'This trick, which literally means "to the guy," distorts a person\'s character subtly or blatantly, undermining their reputation regardless of how compelling their point is.',
#   '“I really deserve an “A” on this paper, professor. Not only did I study during my grandmother’s funeral, but I also passed up the heart transplant surgery, even though that was the first matching donor in 3 years.”',
#   'Having come from the same political party, he is sure to communicate biased and untrue claims about his party-mates',
#   'It is either you are for the US war on terror or against it.',
#   'Gus is Christian or Gus is politically liberal. Gus is a Christian. Therefore, Gus is not politically liberal.',
#   '“I admire the president for being a good role model.” REPLY: “But the New York Times says he’s a lousy role model, so you’re wrong.”',
#   'Radio talk show host, on learning that an association of critical thinking professors had suggested his show as a source of fallacious reasoning: “Who are these people? They talk to maybe 30 people at a time. I talk to 5 million people every day. They could not begin to do what I do. They are just gnats flying around getting in the way.”',
#   'Ms. Drayer, the smartest person in the universe, says the debate is the best class, therefore it is.',
#   'My opponent says I am weak on crime, but I have been one of the most reliable participants in city council meetings.',
#   "A 2005 Gallup Poll found that an estimated 25% of Americans over the age of 18 believe in astrology—or that the position of the stars and planets can affect people's lives.  That is roughly 75,000,000 people.  Therefore, there must be some truth to astrology!",
#   'There is definitely a link between autism and the vaccines given to toddlers. I know this because a Wikipedia entry mentioned numerous studies that found this to be true.',
#   'Whatever happens by chance should be punished, because whatever happens by chance is a departure from law and all departures from law should be punished.',
#   'There you are cheating on your husband, how could you ever tell us anything meaningful about ethics?',
#   'The “prophet” Nostradamus wrote about 500 years ago: Beasts wild with hunger will cross the rivers, The greater part of the battle will be against Hister. He will cause great men to be dragged in a cage of iron, When the son of Germany obeys no law. Surely he must have had some vision of Hitler!',
#   "Mr. Gough supports the cell phone ban and he's an idiot, so we should let teachers keep their cell phones.",
#   'In the race for mayor, Lara says a vote for her opponent will lead to you losing your job.',
#   "Tyler's friends are all obnoxious, he's a bad kid",
#   'Minds, like rivers, can be broad. The broader the river, the shallower it is. Therefore, the broader the mind, the shallower it is.',
#   '(1) William Dembski argues that modern biology supports the idea that there is an intelligent designer who created life. (2) Dembski would say that because he’s religious. Therefore: (3) Modern biology doesn’t support intelligent design',
#   'An abusive attack against someone making the argument, instead of the argument itself, is called a/an',
#   'The temperature has dropped this morning, and I also have a headache. The cold weather must be causing my headache.',
#   'If we legalize marijuana, then more people will try heroin',
#   "Donald Trump Jr. Tweeted: If I had a bowl of skittles and I told you just three would kill you. Would you take a handful? That's our Syrian refugee problem.",
#   '"Annie must like Starbucks because all white girls like Starbucks."',
#   'This technique uses the logic: Everyone else is doing it, you should too!',
#   'I wore my lucky red shirt when I took the test, so that is probably why I did so well on the test.',
#   'Studies show it takes up to seven years for the human body to digest a piece of gum.',
#   'French people are great at kissing. Julie is French. Get me a date!',
#   'Confession is good for the soul.',
#   'This technique using vague positive words that actually hold little meaning.',
#   'That parking attendant who gave me a ticket is as bad as Hitler.',
#   "The academic decathlon, Mr. Iglesias? That's a rich kid thing.",
#   'I guess I should buy my 12-year-old daughter an iPhone. Everyone at her new school has one and I want her to fit in with the other kids.',
#   'Exercise is good. Therefore everybody should exercise.\' "\'I agree,\' said Polly earnestly. \'I mean exercise is wonderful. I mean it builds the body and everything.\'',
#   'Tasha is studying polar and tropical climates on Earth. She learned the following: Tropical climates: Summer and winter temperatures are similar.  Polar climates: Summer temperature is much higher than winter temperature. Tasha wonders why the tropical climate has the same temperature year round, but the polar climate temperature differs greatly.',
#   "I can't trust the mayor or the governor. All politicians must be liars.",
#   "The number of off-leash dogs I've seen in Livingston is completely unacceptable. Let's make our streets safe again by addressing this dog problem, before our city becomes a haven for criminals.",
#   "You're complaining because you have to walk to school? I used to have to give my parents my entire paycheck.",
#   "Robert Downey Jr. thinks everyone should vote. However, Robert Downey Jr. once went to prison for drug use. So, he's obviously wrong.",
#   'We admit that this measure is popular, but we also urge you to recognize that there are so many other bond issues on this ballot it is getting ridiculous.',
#   'I did not complete my homework last night? Well, you did not do yours last weak either.',
#   'Four out of five dentists recommend Happy Glossy Smiley toothpaste brand. Therefore, it must be great.',
#   '"If a black cat crosses your path you will have bad luck."',
#   "Yeah, I think everyone's opinion counts on moral matters like that, but that Lila sleeps around with anything. I know of at least one marriage she's broken up, so why should her opinion count on anything, much less morality?",
#   'The word of Zorbo the Great is flawless and perfect. We know this because it says so in The Great and Infallible Book of Zorbo’s Best and Most Truest Things that are Definitely True and Should Not Ever Be Questioned.',
#   "We're going to celebrate New Year's Eve this way because that's how we've always done it.",
#   'Because you found something difficult to understand, or are unaware of how it works, you made out like it is probably not true.',
#   "I didn't want to the only one not listening to music while I completed my Achieve article, so I listened to music too.",
#   '“Because young male drivers are twice as likely to get into a car accident, they should pay more for car insurance.”',
#   "I don't see how you can say you're an ethical person. It's so hard to get you to do anything; your work ethic is so bad",
#   'men don’t cry',
#   'Dave: For five generations, the men in our family went to Stanford and became doctors, while the women got married and raised children.  Therefore, it is my duty to become a doctor. Kaitlin: Do you want to become a doctor? Dave: It doesn’t matter -- it is our family tradition.  Who am I to break it?',
#   'Either you love me, or you hate me.',
#   'It is immoral to kill an innocent human being.  Fetuses are innocent human  beings.  Therefore, it is immoral to kill fetuses.',
#   'very time Joe goes swimming he is wearing his Speedos. Something about wearing that Speedo must make him want to go swimming.',
#   "Did you really vote for Donald as class treasurer? Didn't you hear that his uncle was imprisoned for embezzling $1.5 million?",
#   "If it wasn't a missile, a bomb, or mechanical failure, then all that's left is a meteorite.",
#   "Royal's promoting their team for the next season by telling people to come join the team because everyone else has.",
#   'Recently, we highlighted a British journalist’s story about the underside of Dubai’s startling ascent. Some in Dubai called foul, including one writer who wants to remind Britons that their own country has a dark side. After all, what to think of a country in which one-fifth of the population lives in poverty?',
#   'If it was raining outside, it would be dark. It’s dark outside, so it must be raining.',
#   'All Greek food causes illness;  when I traveled through Greece, I got food  poisoning.',
#   "If you don't study, you'll fail your test. Then you will do poorly in the class and your GPA will fall. You won't get into a good college, so you'll never get a decent job and you'll end up homeless.",
#   'Justifies a claim because a large group favors it',
#   'I believe that PNoy is the Abraham Lincoln of the Philippines.',
#   'Everyone who gets a college degree is better off.  All people who are better off as a result of getting a degree are good to have conversations with.  Therefore, everyone who gets a college degree is a good person to have a conversation with.',
#   "I want to have myself a merry little Christmas, but I refuse to do as the song suggests and make the yuletide gay.  I don't think sexual preference should have anything to do with enjoying the holiday.",
#   'Mike: It is morally wrong to cheat on your spouse, why on earth would you have done that? Ken: But what is morality exactly? Mike: It’s a code of conduct shared by cultures. Ken: But who creates this code?...',
#   'Jack threw up because he ate Hot Cheetos.',
#   'Many people criticize Thomas Jefferson for being an owner of slaves. But Jefferson was one of our greatest presidents, and his Declaration of Independence is one of the most eloquent pleas for freedom and democracy ever written. Clearly these criticisms are unwarranted.',
#   'Using a double standard or arguing for an unjustified exception.',
#   'Hundreds of thousands of animals are being tortured and killed every year, and for what? So that we can modernize our beauty products and overstock our grocery stores?',
#   "Wife: I'd rather have a dog than a cat Husband: Why do you hate cats?",
#   'Elba: I can’t believe the art critic said my artwork is awful! Rowena: He must have meant it in the old sense of the word -- that your artwork inspired awe! Elba: Yes!  That makes sense now!',
#   'Senator Jill: "We\'ll have to cut education funding this year." Senator Bill: "Why?" Senator Jill: "Well, either we cut the social programs or we live with a huge deficit and we can\'t live with the deficit."',
#   'I passed my math test after going out to the movies the night before. I should go to the movies the night before every math test!',
#   "John: I think we should hire someone to redesign our website. Lola: You're saying we should throw our money away on external resources instead of building up our in-house design team? That's going to hurt our company in the long run.",
#   'According to Freud, your belief in God stems from your need for a strong father figure. So don’t you see that it’s silly to continue believing in God?',
#   'The reason the firmament, a tent-like structure that kept the “waters above” from flooding the earth as described in the Bible, is no longer there today, is because it was destroyed during Noah’s flood.',
#   'Look, the only way to improve social programs is to raise taxes. You have to either raise taxes, or accept that the poor and needy are going to suffer.',
#   '“President Kumail raised taxes, and then the rate of violent crime went up. Kumail is responsible for the rise in crime.”',
#   'Senator Jones wants a strong national defense, but I will not vote for him because he moved to Canada to avoid being drafted for war when he was in college.',
#   '“I know the exam is graded based on performance, but you should give me an A. My cat has been sick, my car broke down, and I’ve had a cold, so it was really hard for me to study!”',
#   'Speaker 1: You should trust the Bible because it’s the Word of God. Speaker 2: How do you know it’s the Word of God? Speaker 1: Because God tells us it is. Speaker 2: Where does God tell us this? Speaker 1: Right here, in the Bible.',
#   'Those who believe in behavior modification obviously want to try to control everyone by subjecting them to rewards and punishments.',
#   'The meteorologist predicted the wrong amount of rain for May. Obviously the meteorologist is unreliable.',
#   '"If you don\'t bring a pencil to class... you will end up sad and alone in life."',
#   '“We must accept the traditions of the men of old time who affirm themselves to be the offspring of the gods - that is what they say - and they must surely have known their own ancestors. How can we doubt the word of the children of the gods?” - Plato, Timaeus',
#   'Which fallacy literally means "He did it himself?"',
#   'Sandra tells her mom, "I deserve to have a later curfew, so you should let me stay out until 10pm!"',
#   'Eugene is silly in class. Harry is his friend, so Harry must be silly, too.',
#   'Fred the Australian stole my wallet. All Australians are thieves!',
# ...
#   'When the judge asked the defendant why he hadn\'t paid his parking fines, he said that he shouldn\'t have to pay them because the sign said \'Fine for parking here\' and so he naturally presumed that it would be fine to park there. Your honor, while my son may have made a bad decision that night while under the influence of alcohol, it shouldn\'t affect the rest of his life. It was just one mistake. He\'s on the varsity swim team. Maury: Please put all my chips on red 21. Dealer: Are you sure you want to do that?  Red 21 just came up in the last spin. Maury:  I didn’t know that!  Thank you!  Put it on black 15 instead.  I can’t believe I almost made that mistake! ["Get Verizon--1 million bucks can\'t be trusted."] Our colleague, Doctor Χ, is too young and inexperienced; we could do without his advice. I would have done my homework, but my refrigerator stopped working.',
#   'You can look cool in our clothes, or you can look like a loser. The president of Honduras is a good leader because he is a leader of the country. Believing that taco bell is healthy for you because everyone else does. Everyone being referred to as comrade. Look at that face! Would anyone vote for that? Can you imagine that as the face of our next president? Look at that face! Could anyone trust that to run the country?',
#   'You have to give me a passing grade. I spent 150 hours on that project and missed every party this quarter. I should receive an \'A\' in this class. After all, if I don\'t get an \'A\' I won\'t get the fellowship that I want. Professor, please, PLEASE reconsider my grade on the Final! I know I only answered 7% of the questions correctly, but I didn’t really deserve an F! In the past week I sprained my ankle, my dog ran away, and my kitchen caught on fire! I think it’s only fair I get a chance to retake the test! "I should receive an \'A\' in this class. I had a tough week!" Hadi begged Eating five candy bars and drinking two sodas before a test helps me get better grades. I did that and got an A on my last test in history. I know I missed assignments, but if you fail me, I will lose my financial aid and have to drop out.',
#   'All chess players are geniuses. Two of my best friends are really introverted, shy people, and they both have cats. That leads to me believe that most cat lovers are really shy. [\'Get two billion people should be alone.\'] Teachers claim that cell phones distract students, but they only say that because teachers have no lives. All required university courses are boring. Teachers don\'t have lives."My best friend said her English class was hard, and the one I\'m in is hard too. All English classes must be hard."',
#   'I guess I should buy my 14 year old a new iPhone since everyone at her school has one. "I\'m gonna get an iPhone because everybody else has an iPhone and they\'re cool." Let’s go buy the iPhone X in spite of the $999 price tag--all of our friends have one already! Everyone is buying the new iPhone that’s coming out this weekend. You have to buy it too Of course we should buy an Apple computer whenever we need a new computer. We have been buying Apple as far back as anyone can remember! Everyone wants the iPhone 11 because it\'s the best phone on the market!',
#   'Everyone is buying the new iPhone that’s coming out this weekend. You have to buy it too Everyone else is doing it! "everyone is doing it" mentality Tries to persuade the reader to do, think or buy something because it is popular or because "everyone" is doing it. Everyone is doing it, you should be too! The reason everyone wants the new "Slap Me Silly Elmo" doll is because this is the hottest toy of the season!',
#   "“Don’t worry about eating fast food. After all, millions of Americans eat it every day.” Almost everyone that was asked said that McDonalds is better than Burger King, so it must be true “Eat great food at our restaurant, or eat sad, boring meals at home.” You are either a leader or a follower. You can go to bed in 5 minutes or you can go to bed in ten minutes. What's your choice? McDonald’s has served 100 billion people in the world. It must be the best fast food restaurant in the world",
#   "MacDougal roots for a British football team. Clearly he's unfit to be a police chief in Ireland. Saying that because one finds something difficult to understand, therefore it's not true Speaker 1: Dr. Singh says meat eating is bad for the environment. Speaker 2: He’s a Sikh. They don’t eat meat. Of course he would say that. He can’t be telling the truth. We can't believe what he says out of that ugly mouth of his. Jack: You should stop smoking - it's bad for you. Jill: Look who's talking! You smoke three packs a day! My opponent argues that we should abolish the soda tax. It's a shame that he wants to encourage people to eat and drink unhealthily. I say we keep it.",
#   "I believe in God because no one can prove that a god doesn't exist. The Bible is filled with stories of God's magic. God exists. How do you know? Because it says so in the Bible. Superstition is a belief or practice resulting from ignorance, fear of the unknown, trust in magic or chance, or a false conception of causation -- unless it is astrology. the claim, as evidence for an idea, that many people believe it, or used to believe it or do it. It says in the Bible that God exists. Since the Bible is God's word, and God never speaks falsely, then everything in the Bible must be true. So, God must exist.",
#   'All people from Pinole are liars [\'Why must we always take such a stupid and naive attitude to ethics?\'] ["Get two billion who can\'t be trusted."] [\'Get a billion people cannot be trusted.\'] [\'Why must we always take such seemingly stupid and uninformed route to ethics?\'] [\'Why must we constantly take such a stupid or uninformed approach to ethics?\']',
#   'The news is fake because so much of the news is fake. "The Senator must be wrong on the issue of taxes because he\'s such a jerk to the people who work for him." "Who is Sam Brownbeck, and why is he saying all those terrible things about rock lyrics? On Nov. 6, Brownbeck, an ambitious Kansas Republican ... convened a hearing billed as "An Example of Violent Music Lyrics on Youth Behavior and Well Being ..." Brownbeck\'s subcommittee, which supervises schools and streets in D.C., has much more important work to do, but the senator, who will run again in 1998, is clearly searching for an issue to give him national prominence." news organizations are Fake News? An NSA whistle-blower, William Binney, said last week that the agency’s surveillance activities put us on \'a slippery slope toward a totalitarian state\' Look Tom, you could go to the police with your information about our questionable accounting practices here at Bentron. But remember, you have a family to feed. Besides you know how rumors of this kind of disloyalty can spread through the industry. You\'ll ever work as an accountant in this town again.',
#   '["Get a trillion dollars can\'t be wrong."] Believing that "runs" occur to statistically independent phenomena such as roulette wheel spins. Eric: For my lottery numbers, I chose 6, 14, 22, 35, 38, 40.  What did you choose? Steve: I chose 1, 2, 3, 4, 5, 6. Eric: You idiot!  Those numbers will never come up! Ten years ago I got a 170 on the LSAT, so I expect to get the same score again. You said that \'runs\' occur to statistically independent phenomena such as roulette wheel spins. ["Get Verizon--1 trillion dollars can\'t go wrong."]',
#   'All living beings come from other living beings.  Therefore, the first forms of life must have come from a living being.  That living being is God. Primitive people believed in gods to explain natural phenomena. We have science, and are not primitive anymore. Therefore, there is no God. Dicky: So how do you think life began? Ralphie: Simple.  Aliens from another planet seeded this planet with life billions of years ago. Dicky: OK, but how did that alien life form begin? Ralphie: Simple.  Aliens from another planet seeded that planet with life. God must exist because every culture has some sort of belief in a higher being. We know God exists because we can see the perfect order of His Creation, an order which demonstrates supernatural intelligence in its design. We haven’t proven aliens didn’t create life on earth, so aliens created life on earth.',
#   "['There are definitely a connection between smoking and drinking energy drinks. I read about it through Wikipedia.'] ['There is definitely a connection between smoking and drinking mixed drinks. I read on it on Wikipedia.'] ['There is definitely the link with smoking and drinking energy drinks. I read about that on Wikipedia.'] ['There is also a link between smoking and drinking alcoholic drinks. I read about them on Wikipedia.'] ['There is definitely a link from smoking & drinking alcoholic drinks. I read about it on Wikipedia.'] ['There is even the link between smoking and drinking energy drinks. I heard about it on Wikipedia.']",
#   '["Get Verizon--1 service we can\'t get wrong."] [\'Get Verizon--1 and customers will be wrong.\'] Either you decide that you can afford this stereo, or decide not to have music for a while ["Get Verizon--1 Your customers can\'t be ignored."] ["Get Verizon--1 if people can\'t get bothered."] [\'Get Verizon--1 and people will be bothered.\']',
#   '"Then we had a death. A 32-year-old woman hemorrhaged to death as a result of a cervical laceration. I finally realized, we weren\'t helping women - we were destroying them." On my walk to work this morning, a woman on her bike nearly ran me off the sidewalk. I hadn\'t realized that cyclists were so aggressive and rude! I knew I should have helped that old lady across the road.  Because I didn’t, I have been having bad Karma all day. The accident was caused by the taxi parking in the street I would never buy a Buick. My father owned two of them and both of them had frequent transmission problems. Buicks obviously break down all the time. People who drive big cars probably hate the environment.',
#   '“against the man;” attacking the individual rather than their position. person 1 : "We should argue with logic facts" person 2: "You should grow a brain before you open your mouth" Boy , those sound like pretty terrible, epicly fascist (hint) robots. Misrepresenting someone’s argument to make it easier to attack Speaker 1: I’m against the war. Speaker 2: You must hate our troops. I have been accused of using an ad hominem approach in trying to defend my research. But those who attack me and my research are also using ad hominem. And they started it!',
#   '[\'Why must we all take such a stupid and uninformed approach to science?\'] "He wouldn\'t make a good president because he looks like a sad muppet." David is so wrong about Luna\'s work ethic. David is just an egotistical jerk with a God complex, what does he know? [\'Why must you always take such a stupid & uninformed approach towards politics?\'] [\'Why must you constantly take such a stupid and uninformed view to science?\'] Not able to defend his position that evolution \'isn\'t true\' Bob says that he knows a scientist who also questions evolution (and presumably isn\'t a primate).',
#   "I think that we should reject what Father Jones has to say about the ethical issues of abortion because he is a Catholic priest. After all, Father Jones is required to hold such views We've got to stop them from banning pornography. Once they start banning one form of literature, they will never stop. Next thing you know, they will be burning all the books! Speaker 1: We are using thousands of people, who are going door to door to help us spread the word about social injustice and the need for change. Speaker: Well then, I can’t be a part of this because I was always been taught that it’s wrong to use people. Adultery, as well as philandering, is wrong. Therefore, we have no biological tendency for multiple sex partners. The numbers on gun violence speak for themselves. We should ban guns in the country! “Feminists want to ban all pornography and punish everyone who looks at it! But such harsh measures are surely inappropriate, so the feminists are wrong: porn and its fans should be left in peace.”",
#   'Children should not go trick or treating, as there always exists the possibility that someone could poison the treats. Children who play violent video games act more violently than those who don’t. Violent video games are directly related to gun violence in schools and should be banned for teens. The school day should start an hour later. Distracting and dangerous mobile devices should be banned from use in vehicles. Allowing people to possess guns is like giving a bomb to a bunch of kids. Some teenagers in our community recently vandalized the park downtown. Teenagers are so irresponsible and destructive.',
#   'Trying to convince others that everyone is doing it or everyone feels this way so they should too. Appealing to popularity or the fact that many people do something as an attempted form of validation Doing something because everyone else is doing it , or a group of people think, in order to persuade one to think the same way. You appealed to popularity or the fact that many people do something as an attempted form of validation. This is an emotional appeal that speaks the concept that many people agree or disagree, so you should, too',
#   "I'm raising money to help cure XYZ disease. If you do not donate, you are part of the problem. An advertisement asking people to give to St. Jude Research Center to help children struggling with cancer. You wouldn't want to let these children die, right? I'm raising funds to help cure XYZ disease. If you don't donate, then you're part of the problem. Either we ban teenagers from possessing cell phones or we continue to let thousands of young students fail their classes. We shouldn't let teenagers keep their phones just because they're upset at losing them; most babies cry when you take their toys away too. Power lines cause cancer.  I met a little boy with cancer who lived just 20 miles from a power line who looked into my eyes and said, in his weak voice, “Please do whatever you can so that other kids won’t have to go through what I am going through.”",
#   "No one can deny that [my theoretical orientation] is the only valid theoretical orientation I’m not a doctor, but I play a doctor on TV, and I wouldn’t dream of using anything but Tylenol for my toughest headaches. While I think most people shouldn't be allowed to falsely claim they need a support animal on airplanes, I really do need my dog to calm me down. It's not my fault my doctor won't give me authorization. My new method of conducting meta-analyses is the most valid there is because it is the only one capable of such validity, the only one that has ever approached such validity, and the only one that is so completely valid. In the four years that I have been marketing my new and improved brand of past-life regressive biocognitive astral-projective hyperaffective-hypnotic-teleological-metatherapy (buy ten sessions and the next one is free!), not one person has proved it is worthless or that I am unethical for providing a therapy I just made up one day when I realized that no one was referring clients to me anymore. That makes clear what a worthwhile therapy this is and how exceptionally ethical I am to provide it. If there is objective morality, then good moral behavior will be rewarded after death.  I want to be rewarded; therefore, morality must be objective."]}

# %%
def get_new_data(data, note, dataset = "data/new_finegrained", threshold = 0):
    new_data = [
        data_point
        for data_point
        in data
        if data_point["meta"]["data_dir"] == dataset and 'note' in data_point.keys() and (data_point['note'] == note or note == None)
    ]

    new_data = [
        data_point 
        for data_point in new_data
        if data_point['predictions']['metrics']['test_f1'] > threshold
    ]

    print(len(new_data))
    return new_data

# %%
_ = get_new_data(data, 'best_hps_final_without_attention', dataset = 'data/bigbench', threshold=0)
# Out:
# 60

# %%
def get_metrics(y_true, y_pred):
    return {
        'f1': f1_score(y_true, y_pred, average = "weighted"),
        'precision': precision_score(y_true, y_pred, average = "weighted"),
        'recall': recall_score(y_true, y_pred, average = 'weighted'),
        'accuracy': accuracy_score(y_true, y_pred)
    }

# %%
def get_unfolded_labels(sample_data):
    label_encoder = sample_data["label_encoder"]
    cbr_labels = sample_data["cbr_labels"]
    all_cbr_labels = []
    for sample_cbr_labels in cbr_labels:
        unfolded_sample_cbr_labels = []
        for retriever_cbr_samples in sample_cbr_labels:
            for filtered_cbr_sample in retriever_cbr_samples:
                for inner_label in filtered_cbr_sample:
                    unfolded_sample_cbr_labels.append(inner_label)
        all_cbr_labels.append(unfolded_sample_cbr_labels)
        
    all_cbr_labels = [
        label_encoder.transform(cbr_labels)
        for cbr_labels
        in all_cbr_labels
    ]
    return all_cbr_labels

# %%
def get_overlap(sample_data):
    label_encoder = sample_data["label_encoder"]
    
    labels = sample_data["predictions"]["label_ids"]
    
    cbr_labels = sample_data["cbr_labels"]
    
    all_cbr_labels = []
    for sample_cbr_labels in cbr_labels:
        unfolded_sample_cbr_labels = []
        for retriever_cbr_samples in sample_cbr_labels:
            for filtered_cbr_sample in retriever_cbr_samples:
                for inner_label in filtered_cbr_sample:
                    unfolded_sample_cbr_labels.append(inner_label)
        all_cbr_labels.append(unfolded_sample_cbr_labels)
        
    all_cbr_labels = [
        label_encoder.transform(cbr_labels)
        for cbr_labels
        in all_cbr_labels
    ]
    
    predicted_labels = np.argmax(sample_data["predictions"]["predictions"], axis = -1)
    correct_predictions = np.where(labels == predicted_labels)[0]

    overlap_count = 0
    for index in correct_predictions:
        if labels[index] in all_cbr_labels[index]:
            overlap_count += 1
    return overlap_count / len(correct_predictions)

# %%
def get_results_df(new_data):
    total_cbr_texts = []
    total_cbr_labels = []
    total_num_cases = []
    total_retrievers = []
    total_overlaps = []
    total_thresholds = []
    total_f1_scores = []
    total_precisions = []
    total_recalls = []
    total_accuracies = []
    total_true_labels = []
    total_predicted_labels = []
    total_f1_scores_climate = []
    total_precisions_climate = []
    total_recalls_climate = []
    total_accuracies_climate = []
    for sample_data in new_data:
        if 'cbr_labels' in sample_data.keys():
            total_num_cases.append(sample_data['meta']['num_cases'])
            total_retrievers.append(' '.join(sample_data['meta']["retrievers"]))
            total_cbr_texts.append(sample_data['cbr'])
            total_cbr_labels.append(get_unfolded_labels(sample_data))
            
            total_overlaps.append(get_overlap(sample_data))
            total_thresholds.append(sample_data['meta']['cbr_threshold'])
        else:
            total_cbr_texts.append(None)
            total_cbr_labels.append(None)
            total_num_cases.append(None)
            total_retrievers.append(None)
            total_overlaps.append(None)
            total_thresholds.append(None)
        
        if 'predictions_climate' in sample_data.keys():
            total_f1_scores_climate.append(sample_data['predictions_climate']['metrics']['test_f1'])
            total_precisions_climate.append(sample_data['predictions_climate']['metrics']['test_precision'])
            total_recalls_climate.append(sample_data['predictions_climate']['metrics']['test_recall'])
            total_accuracies_climate.append(sample_data['predictions_climate']['metrics']['test_accuracy'])
        else:
            total_f1_scores_climate.append(None)
            total_precisions_climate.append(None)
            total_recalls_climate.append(None)
            total_accuracies_climate.append(None)
            
        total_f1_scores.append(sample_data['predictions']['metrics']['test_f1'])
        total_precisions.append(sample_data['predictions']['metrics']['test_precision'])
        total_recalls.append(sample_data['predictions']['metrics']['test_recall'])
        total_accuracies.append(sample_data['predictions']['metrics']['test_accuracy'])
        total_true_labels.append(sample_data['predictions']['label_ids'])
        total_predicted_labels.append(
            np.argmax(sample_data['predictions']['predictions'], axis = -1).tolist()
        )
    
    
        
    results_df = pd.DataFrame({
        'num_cases': total_num_cases,
        'threshold': total_thresholds,
        'retrievers': total_retrievers,
        'overlaps': total_overlaps,
        'f1': total_f1_scores,
        'precision': total_precisions,
        'recall': total_recalls,
        'accuracy': total_accuracies,
        'cbr': np.array(total_cbr_texts).squeeze().tolist(),
        'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
        'label_ids': total_true_labels,
        'predicted_labels': total_predicted_labels,
        'f1_climate': total_f1_scores_climate,
        'precision_climate': total_precisions_climate,
        'recall_climate': total_recalls_climate,
        'accuracy_climate': total_accuracies_climate,
    })
    return results_df

# %% [markdown]
# ### Fine Grained

# %%
new_data = get_new_data(data, "best_hps_final_baseline")
results_df = get_results_df(new_data)
results_df.f1.mean()
# Out:
# 18
# 0.6256211702260767

# %%
new_data = get_new_data(data, "best_hps_final_without_attention")
results_df = get_results_df(new_data)
print(results_df.f1.mean())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].mean()
# Out:
# 18
# 0.5916446984296276
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy              0.0  0.590704   0.596686  0.595000  0.595000
# simcse               0.0  0.590486   0.602600  0.593333  0.593333
# simcse empathy       0.0  0.596712   0.606680  0.600000  0.600000

# %%
new_data = get_new_data(data, "best_hps_final")
results_df = get_results_df(new_data)
print(results_df.f1.mean())
print(results_df.f1.max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].mean()
# Out:
# 21
# 0.6190162279101896
# 0.6430050638282316
# /tmp/ipykernel_2388946/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy         0.322404  0.606562   0.614255  0.610000  0.610000
# simcse          0.525773  0.643005   0.646090  0.646667  0.646667
# simcse empathy  0.630702  0.607849   0.627357  0.612000  0.612000

# %% [markdown]
# ### Coarse Grained

# %%
new_data = get_new_data(data, "best_hps_final_baseline", dataset = "data/coarsegrained")
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
# Out:
# 18
# f1           0.782848
# precision    0.789266
# recall       0.787224
# accuracy     0.787224
# dtype: float64
# f1           0.813135
# precision    0.812066
# recall       0.817814
# accuracy     0.817814
# dtype: float64

# %%
new_data = get_new_data(data, "best_hps_final_without_attention", dataset = "data/coarsegrained", threshold = 0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['accuracy', 'precision', 'recall', 'f1']].mean()
# Out:
# 19
# accuracy     0.783507
# precision    0.777657
# recall       0.783507
# f1           0.778725
# dtype: float64
# accuracy     0.805668
# precision    0.800807
# recall       0.805668
# f1           0.800680
# dtype: float64
#                 accuracy  precision    recall        f1
# retrievers
# empathy         0.768219   0.762251  0.768219  0.764453
# simcse          0.803933   0.800543  0.803933  0.799332
# simcse empathy  0.773279   0.765336  0.773279  0.767830

# %%
new_data = get_new_data(data, "best_hps_final", dataset = "data/coarsegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['accuracy', 'precision', 'recall', 'f1']].mean()
# Out:
# 21
# accuracy     0.779834
# precision    0.782774
# recall       0.779834
# f1           0.776281
# dtype: float64
# accuracy     0.801619
# precision    0.801724
# recall       0.801619
# f1           0.795360
# dtype: float64
# /tmp/ipykernel_2388946/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 accuracy  precision    recall        f1
# retrievers
# empathy         0.793522   0.799528  0.793522  0.790770
# simcse          0.774629   0.774732  0.774629  0.772452
# simcse empathy  0.771761   0.774147  0.771761  0.766476

# %% [markdown]
# ### Big Bench

# %%
new_data = get_new_data(data, None, dataset = "data/bigbench")
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].max()
# Out:
# 249
# accuracy     0.789042
# precision    0.761081
# recall       0.789042
# f1           0.764592
# dtype: float64
# accuracy     0.997619
# precision    0.997630
# recall       0.997619
# f1           0.997619
# dtype: float64
# /tmp/ipykernel_2388946/40003336.py:51: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr': np.array(total_cbr_texts).squeeze().tolist(),
# /tmp/ipykernel_2388946/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy         0.975177  0.954781   0.954898  0.954762  0.954762
# simcse          0.990881  0.966685   0.966879  0.966667  0.966667
# simcse empathy  0.979112  0.911998   0.915080  0.911905  0.911905

# %%
new_data = get_new_data(data, "best_hps_final_baseline", dataset = "data/bigbench")
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
# Out:
# 18
# accuracy     0.851455
# precision    0.886535
# recall       0.851455
# f1           0.849502
# dtype: float64
# accuracy     0.997619
# precision    0.997630
# recall       0.997619
# f1           0.997619
# dtype: float64

# %%
new_data = get_new_data(data, "best_hps_final_without_attention", dataset = "data/bigbench", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].max()
# Out:
# 41
# accuracy     0.826190
# precision    0.829776
# recall       0.826190
# f1           0.824667
# dtype: float64
# accuracy     0.942857
# precision    0.944043
# recall       0.942857
# f1           0.942916
# dtype: float64
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy              0.0  0.942916   0.944043  0.942857  0.942857
# simcse               0.0  0.921416   0.921413  0.921429  0.921429
# simcse empathy       0.0  0.842674   0.842838  0.842857  0.842857

# %%
new_data = get_new_data(data, "best_hps_final", dataset = "data/bigbench", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].max()
# Out:
# 42
# accuracy     0.782710
# precision    0.789373
# recall       0.782710
# f1           0.782221
# dtype: float64
# accuracy     0.911905
# precision    0.915080
# recall       0.911905
# f1           0.911998
# dtype: float64
# /tmp/ipykernel_2388946/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy         0.975177  0.864418   0.865343  0.864286  0.864286
# simcse          0.989510  0.861946   0.862026  0.861905  0.861905
# simcse empathy  0.979112  0.911998   0.915080  0.911905  0.911905

# %% [markdown]
# ### New Fine Grained

# %%
new_data = get_new_data(data, "best_hps_final_baseline", dataset = "data/new_finegrained", threshold  = 0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
# Out:
# 94
# f1           0.400703
# precision    0.421119
# recall       0.409751
# accuracy     0.409751
# dtype: float64
# f1           0.629232
# precision    0.649869
# recall       0.622356
# accuracy     0.622356
# dtype: float64

# %%
new_data = get_new_data(data, "best_hps_final_without_attention", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].mean()
# Out:
# 40
# f1           0.497668
# precision    0.506981
# recall       0.502341
# accuracy     0.502341
# dtype: float64
# f1           0.598112
# precision    0.614553
# recall       0.595166
# accuracy     0.595166
# dtype: float64
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# empathy              0.0  0.572369   0.579059  0.577039  0.577039
# simcse               0.0  0.586747   0.598886  0.585887  0.585887
# simcse empathy       0.0  0.395183   0.403464  0.404162  0.404162

# %%
new_data = get_new_data(data, "best_hps_final", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['overlaps', 'f1', 'precision', 'recall', 'accuracy']].mean()
# Out:
# 49
# f1           0.512411
# precision    0.526223
# recall       0.512670
# accuracy     0.512670
# dtype: float64
# f1           0.561420
# precision    0.577600
# recall       0.558912
# accuracy     0.558912
# dtype: float64
# /tmp/ipykernel_2388946/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 overlaps        f1  precision    recall  accuracy
# retrievers
# simcse          0.794690  0.489436   0.502549  0.490181  0.490181
# simcse empathy  0.566083  0.534466   0.548951  0.534260  0.534260

# %% [markdown]
# ## Best Hps

# %% [markdown]
# ### New Finegrained

# %%
new_data = get_new_data(data, note = "best_hps_final_baseline_best_ps", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
# Out:
# 18
# f1           0.501514
# precision    0.517504
# recall       0.503525
# accuracy     0.503525
# dtype: float64
# f1           0.532737
# precision    0.540722
# recall       0.537764
# accuracy     0.537764
# dtype: float64

# %%
new_data = get_new_data(data, note = "best_hps_final_without_attention_best_ps", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['accuracy', 'precision', 'recall', 'f1']].max()
# Out:
# 18
# accuracy     0.535247
# precision    0.542838
# recall       0.535247
# f1           0.532134
# dtype: float64
# accuracy     0.540785
# precision    0.551131
# recall       0.540785
# f1           0.539524
# dtype: float64
#                 accuracy  precision    recall        f1
# retrievers
# empathy         0.531722   0.535219  0.531722  0.526820
# simcse          0.540785   0.551131  0.540785  0.539524
# simcse empathy  0.540785   0.543191  0.540785  0.530175

# %%
new_data = get_new_data(data, note = "best_hps_final_best_ps", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['accuracy', 'precision', 'recall', 'f1']].mean()
# Out:
# 75
# accuracy     0.550211
# precision    0.562931
# recall       0.550211
# f1           0.548913
# dtype: float64
# accuracy     0.574018
# precision    0.593917
# recall       0.574018
# f1           0.571961
# dtype: float64
# /tmp/ipykernel_2404724/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 accuracy  precision    recall        f1
# retrievers
# simcse          0.550261   0.563291  0.550261  0.549252
# simcse empathy  0.549849   0.560295  0.549849  0.546428

# %%
results_df.groupby('num_cases')[['accuracy', 'precision', 'recall', 'f1']].mean()
# Out:
#            accuracy  precision    recall        f1
# num_cases
# 1          0.540785   0.549701  0.540785  0.535543
# 2          0.570997   0.593917  0.570997  0.571961
# 3          0.555891   0.570874  0.555891  0.557301
# 4          0.559248   0.570435  0.559248  0.557400
# 5          0.525680   0.525849  0.525680  0.521101
# 6          0.528701   0.548948  0.528701  0.531194

# %% [markdown]
# ### Results with Electra

# %%
new_data = get_new_data(data, note = "best_hps_final_best_ps_electra", dataset = "data/coarsegrained", threshold=0)
results_df = get_results_df(new_data)
results_df[['accuracy_climate', 'precision_climate', 'recall_climate', 'f1_climate']].max()
# Out:
# 30
# /tmp/ipykernel_2739099/1644265854.py:67: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
# accuracy_climate     0.459627
# precision_climate    0.585895
# recall_climate       0.459627
# f1_climate           0.466208
# dtype: float64

# %%
new_data = get_new_data(data, note = "best_hps_final_best_ps_electra", dataset = "data/new_finegrained", threshold=0)
results_df = get_results_df(new_data)
print(results_df[['accuracy', 'precision', 'recall', 'f1']].mean())
print(results_df[['accuracy', 'precision', 'recall', 'f1']].max())
results_df.groupby('retrievers')[['accuracy', 'precision', 'recall', 'f1']].max()
# Out:
# 60
# accuracy     0.572105
# precision    0.579634
# recall       0.572105
# f1           0.570083
# dtype: float64
# accuracy     0.631420
# precision    0.638502
# recall       0.631420
# f1           0.627227
# dtype: float64
# /tmp/ipykernel_2739099/1644265854.py:67: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#                 accuracy  precision    recall        f1
# retrievers
# empathy         0.607251   0.622128  0.607251  0.609985
# simcse          0.631420   0.638502  0.631420  0.627227
# simcse empathy  0.498489   0.518512  0.498489  0.501245

# %%
results_df.groupby('num_cases')[['accuracy', 'precision', 'recall', 'f1']].max()
# Out:
#            accuracy  precision    recall        f1
# num_cases
# 1          0.570997   0.579555  0.570997  0.569204
# 2          0.607251   0.622128  0.607251  0.609985
# 5          0.631420   0.638502  0.631420  0.627227

# %% [markdown]
# ### Analysis on the stuff that help the model with CBR

# %%
cbr_data = get_new_data(data, note = "best_hps_final_best_ps", dataset = "data/new_finegrained", threshold=0)
cbr_model_df = get_results_df(cbr_data)
cbr_model_df.head(3)
# Out:
# 25
# /tmp/ipykernel_2274529/40003336.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   'cbr_labels': np.array(total_cbr_labels).squeeze().tolist(),
#     num_cases  threshold      retrievers  overlaps        f1  precision  \
# 0           4  -10000000          simcse  0.790698  0.519892   0.535958
# 1           4  -10000000          simcse  0.762162  0.561420   0.576230
# 2           4  -10000000          simcse  0.762162  0.561420   0.576230
# 3           4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 4           4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 5           4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 6           4  -10000000          simcse  0.762162  0.561420   0.576230
# 7           4  -10000000          simcse  0.762162  0.561420   0.576230
# 8           4  -10000000          simcse  0.762162  0.561420   0.576230
# 9           4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 10          4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 11          4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 12          4  -10000000          simcse  0.762162  0.561420   0.576230
# 13          4  -10000000          simcse  0.762162  0.561420   0.576230
# 14          4  -10000000          simcse  0.762162  0.561420   0.576230
# 15          4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 16          4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 17          4  -10000000  simcse empathy  0.879121  0.546428   0.560295
# 18          1  -10000000          simcse  0.541899  0.538329   0.547329
# 19          2  -10000000          simcse  0.603175  0.571961   0.593917
# 20          3  -10000000          simcse  0.739130  0.557301   0.570874
# 21          1  -10000000          simcse  0.519553  0.535233   0.549965
# 22          2  -10000000          simcse  0.603175  0.571961   0.593917
# 23          3  -10000000          simcse  0.739130  0.557301   0.570874
# 24          1  -10000000          simcse  0.519553  0.535233   0.549965
#
#       recall  accuracy                                                cbr  \
# 0   0.519637  0.519637  [Either go to the party or spend the night in ...
# 1   0.558912  0.558912  [Either go to the party or spend the night in ...
# 2   0.558912  0.558912  [Either go to the party or spend the night in ...
# 3   0.549849  0.549849  [Either go to the party or spend the night in ...
# 4   0.549849  0.549849  [Either go to the party or spend the night in ...
# 5   0.549849  0.549849  [Either go to the party or spend the night in ...
# 6   0.558912  0.558912  [Either go to the party or spend the night in ...
# 7   0.558912  0.558912  [Either go to the party or spend the night in ...
# 8   0.558912  0.558912  [Either go to the party or spend the night in ...
# 9   0.549849  0.549849  [Either go to the party or spend the night in ...
# 10  0.549849  0.549849  [Either go to the party or spend the night in ...
# 11  0.549849  0.549849  [Either go to the party or spend the night in ...
# 12  0.558912  0.558912  [Either go to the party or spend the night in ...
# 13  0.558912  0.558912  [Either go to the party or spend the night in ...
# 14  0.558912  0.558912  [Either go to the party or spend the night in ...
# 15  0.549849  0.549849  [Either go to the party or spend the night in ...
# 16  0.549849  0.549849  [Either go to the party or spend the night in ...
# 17  0.549849  0.549849  [Either go to the party or spend the night in ...
# 18  0.540785  0.540785  [Either go to the party or spend the night in ...
# 19  0.570997  0.570997  [Either go to the party or spend the night in ...
# 20  0.555891  0.555891  [Either go to the party or spend the night in ...
# 21  0.540785  0.540785  [Either go to the party or spend the night in ...
# 22  0.570997  0.570997  [Either go to the party or spend the night in ...
# 23  0.555891  0.555891  [Either go to the party or spend the night in ...
# 24  0.540785  0.540785  [Either go to the party or spend the night in ...
#
#                                            cbr_labels  \
# 0   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 1   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 2   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 3   [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 4   [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 5   [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 6   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 7   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 8   [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 9   [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 10  [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 11  [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 12  [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 13  [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 14  [[10, 1, 3, 1], [11, 11, 11, 11], [7, 7, 7, 7]...
# 15  [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 16  [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 17  [[10, 1, 3, 1, 3, 8, 8, 3], [11, 11, 11, 11, 1...
# 18  [[10], [11], [7], [5], [3], [11], [0], [8], [1...
# 19  [[10, 1], [11, 11], [7, 7], [5, 3], [3, 7], [1...
# 20  [[10, 1, 3], [11, 11, 11], [7, 7, 7], [5, 3, 1...
# 21  [[10], [11], [7], [5], [3], [11], [0], [8], [1...
# 22  [[10, 1], [11, 11], [7, 7], [5, 3], [3, 7], [1...
# 23  [[10, 1, 3], [11, 11, 11], [7, 7, 7], [5, 3, 1...
# 24  [[10], [11], [7], [5], [3], [11], [0], [8], [1...
#
#                                             label_ids  \
# 0   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 1   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 2   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 3   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 4   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 5   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 6   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 7   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 8   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 9   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 10  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 11  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 12  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 13  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 14  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 15  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 16  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 17  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 18  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 19  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 20  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 21  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 22  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 23  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 24  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
#
#                                      predicted_labels
# 0   [3, 11, 7, 5, 7, 7, 0, 0, 0, 3, 1, 7, 1, 11, 1...
# 1   [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 2   [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 3   [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 4   [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 5   [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 6   [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 7   [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 8   [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 9   [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 10  [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 11  [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 12  [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 13  [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 14  [2, 11, 12, 5, 11, 11, 0, 0, 12, 3, 1, 7, 1, 1...
# 15  [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 16  [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 17  [11, 11, 3, 12, 11, 3, 0, 0, 0, 3, 1, 7, 1, 9,...
# 18  [11, 11, 2, 5, 4, 3, 0, 8, 0, 3, 1, 7, 1, 9, 1...
# 19  [2, 11, 2, 3, 11, 0, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 20  [10, 11, 7, 3, 11, 3, 0, 0, 12, 3, 1, 7, 1, 9,...
# 21  [11, 11, 3, 11, 7, 5, 0, 8, 12, 3, 1, 7, 11, 7...
# 22  [2, 11, 2, 3, 11, 0, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 23  [10, 11, 7, 3, 11, 3, 0, 0, 12, 3, 1, 7, 1, 9,...
# 24  [11, 11, 3, 11, 7, 5, 0, 8, 12, 3, 1, 7, 11, 7...

# %%
base_data = get_new_data(data, note = "best_hps_final_baseline_best_ps", dataset = "data/new_finegrained", threshold=0)
base_data_df = get_results_df(base_data)
base_data_df.head(3)
# Out:
# 18
#    num_cases threshold retrievers overlaps        f1  precision    recall  \
# 0       None      None       None     None  0.532737   0.540722  0.537764
# 1       None      None       None     None  0.499677   0.516139  0.501511
# 2       None      None       None     None  0.499677   0.516139  0.501511
# 3       None      None       None     None  0.499677   0.516139  0.501511
# 4       None      None       None     None  0.499677   0.516139  0.501511
# 5       None      None       None     None  0.499677   0.516139  0.501511
# 6       None      None       None     None  0.499677   0.516139  0.501511
# 7       None      None       None     None  0.499677   0.516139  0.501511
# 8       None      None       None     None  0.499677   0.516139  0.501511
# 9       None      None       None     None  0.499677   0.516139  0.501511
# 10      None      None       None     None  0.499677   0.516139  0.501511
# 11      None      None       None     None  0.499677   0.516139  0.501511
# 12      None      None       None     None  0.499677   0.516139  0.501511
# 13      None      None       None     None  0.499677   0.516139  0.501511
# 14      None      None       None     None  0.499677   0.516139  0.501511
# 15      None      None       None     None  0.499677   0.516139  0.501511
# 16      None      None       None     None  0.499677   0.516139  0.501511
# 17      None      None       None     None  0.499677   0.516139  0.501511
#
#     accuracy   cbr cbr_labels  \
# 0   0.537764  None       None
# 1   0.501511  None       None
# 2   0.501511  None       None
# 3   0.501511  None       None
# 4   0.501511  None       None
# 5   0.501511  None       None
# 6   0.501511  None       None
# 7   0.501511  None       None
# 8   0.501511  None       None
# 9   0.501511  None       None
# 10  0.501511  None       None
# 11  0.501511  None       None
# 12  0.501511  None       None
# 13  0.501511  None       None
# 14  0.501511  None       None
# 15  0.501511  None       None
# 16  0.501511  None       None
# 17  0.501511  None       None
#
#                                             label_ids  \
# 0   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 1   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 2   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 3   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 4   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 5   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 6   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 7   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 8   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 9   [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 10  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 11  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 12  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 13  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 14  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 15  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 16  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
# 17  [10, 11, 5, 8, 7, 8, 0, 0, 0, 3, 1, 7, 1, 9, 1...
#
#                                      predicted_labels
# 0   [10, 11, 11, 3, 7, 0, 0, 0, 0, 3, 1, 11, 11, 1...
# 1   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 2   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 3   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 4   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 5   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 6   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 7   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 8   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 9   [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 10  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 11  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 12  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 13  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 14  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 15  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 16  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...
# 17  [2, 11, 2, 3, 7, 11, 0, 0, 0, 3, 8, 8, 3, 11, ...

# %%
base_model_index = 1
cbr_model_index = 19

wrong_predictions_in_base_model = np.where(base_data_df.iloc[base_model_index]['predicted_labels'] != base_data_df.iloc[base_model_index]['label_ids'])[0]
predictions_correct_by_cbr = np.where(cbr_model_df.iloc[cbr_model_index]['predicted_labels'] == cbr_model_df.iloc[cbr_model_index]['label_ids'])[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb Cell 38 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> cbr_model_index = 19
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> wrong_predictions_in_base_model = np.where(base_data_df.iloc[base_model_index]['predicted_labels'] != base_data_df.iloc[base_model_index]['label_ids'])[0]
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> predictions_correct_by_cbr = np.where(cbr_model_df.iloc[cbr_model_index]['predicted_labels'] == cbr_model_df.iloc[cbr_model_index]['label_ids'])[0]
#
# NameError: name 'cbr_model_df' is not defined

# %%
indices_of_interest = np.intersect1d(wrong_predictions_in_base_model, predictions_correct_by_cbr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb Cell 39 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> indices_of_interest = np.intersect1d(wrong_predictions_in_base_model, predictions_correct_by_cbr)
#
# NameError: name 'predictions_correct_by_cbr' is not defined

# %%
labels_for_the_indices_of_interest = [base_data_df.iloc[base_model_index]['label_ids'][i] for i in indices_of_interest]
print(labels_for_the_indices_of_interest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb Cell 40 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X54sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> labels_for_the_indices_of_interest = [base_data_df.iloc[base_model_index]['label_ids'][i] for i in indices_of_interest]
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X54sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(labels_for_the_indices_of_interest)
#
# NameError: name 'indices_of_interest' is not defined

# %%
cbr_labels_for_the_indices_of_interest = [cbr_model_df.iloc[cbr_model_index]['cbr_labels'][i] for i in indices_of_interest]
print(cbr_labels_for_the_indices_of_interest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb Cell 41 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X55sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cbr_labels_for_the_indices_of_interest = [cbr_model_df.iloc[cbr_model_index]['cbr_labels'][i] for i in indices_of_interest]
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpulogin.lambda.armasuisse.ch/cluster/raid/home/zhivar.sourati/logical-fallacy-identification/CBR/analysis_on_overlap.ipynb#X55sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(cbr_labels_for_the_indices_of_interest)
#
# NameError: name 'indices_of_interest' is not defined

# %%
label_encoder = cbr_data[0]['label_encoder']

test_df = pd.read_csv(os.path.join('data/new_finegrained', "test.csv"))
test_df = test_df[~test_df["label"].isin(bad_classes)]
test_df['label'] = label_encoder.transform(test_df['label'])

# %%
for index, label, cbr in zip(indices_of_interest, labels_for_the_indices_of_interest, cbr_labels_for_the_indices_of_interest):
    print(label, cbr, test_df['text'].iloc[index])
    print(cbr_model_df.iloc[cbr_model_index]['cbr'][index])
    print('--------')
# Out:
# 1 [1 1] Everyone is going to get the new smart phone when it comes out this weekend. Why aren’t you?
# "I'm gonna get an iPhone because everybody else has an iPhone and they're cool." Everyone wants the iPhone 11 because it's the best phone on the market!
# --------
# 7 [7 7] surgeons have X-rays to guide them during an operation, lawyers have briefs to guide them during a trial, carpenters have blueprints to guide them when they are building a house. Why, then, shouldn’t students be allowed to look at their textbooks during an examination?
# Doctors refer to medical books all the time when they are treating patients. In the same way, I should be allowed to use a textbook in my medical exam. If I say that a surgeon should be allowed to use a guidebook to carry out surgery like a student can use open notes on a test, I have made a
# --------
# 1 [1 1] it is used to promote something based on popularity
# Argues that because something is popular, it must be right. You appealed to popularity or the fact that many people do something as an attempted form of validation.
# --------
# 9 [2 7] The Soviet Union collapsed after taking up atheism. Therefore, we must avoid atheism for the same reasons.
# Which fallacy is the following example? "By rejecting God, you are rejecting goodness, kindness, and love itself." I don't believe in God. One reason is that I think he is evil. And by the way, there is no such thing as "evil;" it is just our evaluation of what we believe is wrong.
# --------
# 2 [11 11] Last year I wanted to quit school because my friends treated me like an outcast and talked about me to my friends. I felt betrayed and sad all of the time but now I think I have a place at my new middle school.
# Teachers don't have lives."My best friend said her English class was hard, and the one I'm in is hard too. All English classes must be hard." My friend said her Math class was hard, and the one I’m in is hard, too. All Math classes must be hard!
# --------
# 10 [2 2] Unless you can close your eyes to abuse, write a check to save this puppy.
# We have a responsibility to care for this poor lost dog. A commercial shows images of animals in need to persuade the audience to make donations.
# --------
# 8 [12 10] "'What about Red Herring, ma'am?'' "'I'm not sure. Is Red Herring a red herring? Or is it the fact that we're meant to think Red Herring is a red herring that is actually the red herring?' "'Or perhaps the fact you're meant to think Red Herring isn't a red herring is what makes Red Herring a red herring after all.' "'We're talking serious metaherrings here.'"
# "If you believe that I am wrong, prove to me that I am." When a statement falsely claims or assumes an "either / or" situation, when in fact there is at least one additional logically valid option, it is called...
# --------
# 11 [ 3 11] "Everyone wants to be an English teacher."
# "He's the best teacher I've ever had because he's the best teacher I've known." If you allow the students to redo this test, they are going to want to redo every assignment for the rest of the year.
# --------
# 2 [ 2 10] You've got to donate to the hockey team. They are helping build schools in Uganda. Imagine all of those poor and hungry kids there.
# An advertisement asking people to give to St. Jude Research Center to help children struggling with cancer. You wouldn't want to let these children die, right? I'm raising funds to help cure XYZ disease. If you don't donate, then you're part of the problem.
# --------
# 1 [12  2] Mark: Do you believe in virgin births? Sue: You mean that babies are born virgins? Mark: I mean birth without fertilization. Sue: No. Mark: How could you not believe in virgin births? Roughly two billion people believe in them, don’t you think you should reconsider your position?
# Are you one of those stupid religious people that reject science? Don't you want the best for your baby?
# --------
# 10 [12 11] Too much candy can cause cavities. You should avoid eating any candy unless you want cavities.
# "Good source of Vitamin D"...*doesn't mention the terrible amounts of sugar. "The government should not prohibit drugs. Otherwise the government should also ban alcohol or cigarettes. And then fatty food and junk food would have to be regulated too. The next thing you know, the government would force us to brush our teeth and do exercises everyday."
# --------
# 9 [9 6] The report suggests that 'the rise in violent offending and the explosion in the sales of iPods and other portable media devices is more than coincidental,' and asks, rather provocatively, 'Is There an iCrime Wave?' The report notes that nationally, violent crime fell every year from 1993 to 2004, before rising in 2005 and 2006, just as 'America’s streets filled with millions of people visibly wearing, and being distracted by, expensive electronic gear.'
# President Jones raised taxes, and then the rate of violent crime went up. Jones is responsible for the rise in crime. "Advocates of legalized abortion predicted it would solve our social problems. Instead, this destruction of one-fourth of a generation has left a more violent society in its wake: Child abuse has exploded, from 167,000 estimated cases in 1973 to 2.4 million in 1989, according to the National Center of Child Abuse and Neglect - a 1,400% increase. Teen suicide, among non-aborted and thus presumably "wanted" children, has doubled. Violent crime has more than doubled."
# --------
# 3 [3 7] Paranormal activity is real because I've seen a ghost.
# Ghosts exist.... because I saw a ghost in my closet If I’m psychic, I will be able to see dead people. I see dead people, therefore I’m psychic.
# --------
# 8 [8 8] My wife wants to talk about cleaning out the garage, so I asked her what she wants to do with our patio furniture. Now she's shopping for new patio furniture and not asking me about the garage.
# I want to sell my house for $400,000. A buyer wants it for $100,000, so I must sell it for $250,000. Your mom thinks you spend too much time playing video games. You bring up that she spends too much time shopping.
# --------
# 11 [11  5] If you forget to floss, you will get cavities, and if you get cavities, you will lose all your teeth by the time you're 30.
# If you don’t eat breakfast, you’ll slouch in your desk. If you slouch in your desk, you’ll hurt your back. If you hurt your back, you’ll never become President. “four out of five dentists agree that brushing your teeth makes your life meaningful”
# --------
# 0 [11 11] J: Cats are better than dogs. V: Dogs are better. J: You are a lazy person. You won't even be able to take care of a dog.
# A lion is a cat and cats are good pets so a lion must be a good pet. My cat sleeps all day, so cats must be pretty lazy.
# --------
# 11 [1 4] Daniel was a precocious child and had a liking for logic. He reasoned that atoms are invisible, and that he was made of atoms and therefore invisible too. Unfortunately, despite his thinky skills, he lost the game of hide and go seek.
# Red had come up six times in a row on the roulette wheel, so Greg knew that it was close to certain that black would be next up. Suffering an economic form of natural selection with this thinking, he soon lost all of his savings. "I see nobody on the road," said Alice. "I only wish I had such eyes," the king remarked..."To be able to see Nobody! And at that distance, too! Why it's as much as I can do to see real people, by this light."
# --------
# 11 [11  2] Everyone knows that teenagers are lazy
# “If we let teenagers wear whatever they want to school, they will no longer respect the rules and academic performance will decline.” If we don’t teach teens to work harder, the human race is doomed.
# --------
# 0 [11 11] Bill, you drive a beat-up car from the 1980s. For this reason, we can never allow you to be a lifeguard at the community pool.
# That type of car is poorly made; a friend of mine has one, and it continually gives him trouble. Don't ever gamble! Once you start, you won't be able to stop, and you'll end up bankrupt.
# --------
# 2 [12  4] I believe that when we die, we are all given new, young, perfect bodies, and we spend eternity with those whom we love. I can’t imagine the point of life if it all just ends when we die!
# What’s the point of living?  We’re all going to die anyway. All living beings come from other living beings.  Therefore, the first forms of life must have come from a living being.  That living being is God.
# --------
# 1 [1 8] In this election, we've seen the highest voter turnout ever recorded. If you have any doubts about Tyler Espinoza's qualifications, just look at how many people have come out to vote for him.
# "The majority of people are voting for John Doe, so he must be the best candidate." We admit that the measure is popular. But we also urge you to note that there are so many bond issues on the ballot that the whole thing is getting ridiculous.
# --------
# 0 [0 6] My opponent in this election claims to have the best interests of our community at heart. However, he is separated from his family. Isn’t family the basic unit of society? How can we entrust the concerns of the community to someone who was not able to keep his family together?
# A politician arguing that his opponent cannot possibly be a good choice for women because he has been married and divorced five times. My opponent in the election keeps claiming that he wants to give tax credits to poor people. That means that he wants to raise taxes for the middle class.
# --------
# 12 [11  0] How many school shootings should we tolerate before we change the gun laws?
# The numbers on gun violence speak for themselves. We should ban guns in the country! The Democrats support more aggressive gun control laws. Can you believe they want to deny repeat offenders and those on the terrorist watch list their rights?
# --------
# 3 [0 0] I view any discussion concerning the limiting of therapy as morally wrong, that is why I do not accept it.
# I cannot listen to anyone who does not share my social and political values. I think that we should reject what Father Jones has to say about the ethical issues of abortion because he is a Catholic priest. After all, Father Jones is required to hold such views
# --------
# 6 [3 2] What I object to most about those people who oppose capital punishment is that they believe that the lives of convicted murderers are more important than the lives of the police and prison guards who protect us. But, obviously, since the lives of those who protect us are of the greatest value, no one should oppose capital punishment.
# Executions are moral because we must have a death penalty to discourage violent crime. If there is no objective morality, then all the bad people will not be punished for their bad behavior after death.  I don’t like that; therefore, morality must be objective.
# --------
# 2 [2 2] an attempt to persuade the reader/audience based on feelings or emotions; emotional response
# Words with strong feelings that bring about feelings in the reader. Strong words (+ or -) specifically used to sway the reader When an advertiser tries to make a connection with the audience emotionally through sappy stories, music, sad puppies, etc...
# --------
# 0 [ 0 11] But, Dad, I know you smoked when you were my age, so how can you tell me not to do it?
# Mother: You should stop smoking. It's harmful to your health. Daughter: Why should I listen to you? You started smoking when you were 16! My father smoked four packs of cigarettes a day since age fourteen and lived until age sixty-nine. Therefore, smoking really can’t be that bad for you.
# --------
# 11 [ 3 11] Duke University has the best basketball player in the NCAA, therefore they will win the tournament this year.
# "She is the best candidate for president because she is better than the other candidates!" The last Democrat winner of the New Hampshire primary won the general election. This year, the winner of the New Hampshire primary will win the general election.
# --------
# 8 [10 10] Roommate A: We need to talk about your dog. He keeps peeing everywhere and making a mess. Roommate B: It's not as big of a problem as your cat. The thing sheds all over my clothes!
# ['At a recent house party, the discussion has turned to domestic issues, and your friend asks you are you a cat or or dog person?"'] ['At the recent house party, the conversation has turned towards your pets, and your friend questions you “Are you a cat or a dog person']
# --------
# 11 [0 0] This clinic sure makes a lot of money. Each of the psychologists who work there must earn a large income.
# ['Researchers are frauds that still earn huge salaries'] ['Researchers are frauds who only get high salaries']
# --------
# 3 [ 8 10] The witchcraft problem is the most urgent spiritual crisis in the world today. Why? Because witches threaten our very souls.
# There is a global recession and more people are becoming hungry and desperate. Crimes of theft and robbery have been increasing at an alarming rate lately. The only way to solve this problem is by reinstating the death penalty We either ban hairspray or the world will end.
# --------
# 8 [ 6 11] The city should not be singling out our company's problems at our chemical storage facilities, when the EPA records indicate the city's very own landfill has been cited as needing improvements. The council needs to clean up its own mess, before they go after us.
# Al Gore feels that all companies are irresponsible and should be punished for allowing emissions which causes global warming. Habib didn't remember to take out the trash this morning. It will pile up and the neighbors will complain and the health inspectors will come and take away the kids.
# --------
# 11 [11 11] "If you don't get an A in Mr. K's class you will fail high school, never graduate, and end up fighting people for nickels under freeway as a career"
# If I don't take the right classes in high school, then I won't be able to get into a good college. If I don't get into a good college, then I won't be able to get a job. If I can't get a job, then I am going to end up homeless. I failed my AP vocab test so clearly I'm going to fail the class. Then I won't get into college and will never get a job. I will have to live in my parents' basement for the rest of my life. My life is ruined
# --------
# 11 [11  0] A person hanging out in a bar will be an alcoholic
# If indoor smoking laws are passed for bars, the bars will go out of business since people who drink, smoke while they drink. Dad drank at parties, too
# --------
# 2 [6 0] You should choose to work more overtime at the same rate of pay. After all, you wouldn’t want to lose your job, would you?
# If you told a person, "I think we should all stay inside to bend the curve of COVID-19" and they replied, "so I guess you want people to lose their jobs then," A: The Government should enact minimum-wage legislation so that workers are not exploited. B: Nonsense. You say that only because you cannot find a good job.
# --------
# 11 [7 7] "All elephants are big. Some boys are big. Therefore some boys are elephants."
# All lions are animals. All cats are animals. Therefore, all lions are cats. No donkeys are fish. Some asses are donkeys. Therefore, some asses are fish.
# --------
# 2 [2 2] “I really deserve an “A” on this paper, professor. Not only did I study during my grandmother’s funeral, but I also passed up the heart transplant surgery, even though that was the first matching donor in 3 years.”
# You have to give me a passing grade. I spent 150 hours on that project and missed every party this quarter. I should receive an 'A' in this class. After all, if I don't get an 'A' I won't get the fellowship that I want.
# --------
# 0 [ 8 12] There you are cheating on your husband, how could you ever tell us anything meaningful about ethics?
# A man who has cheated on his spouse is confronted by a friend who tells him that it is wrong. The man begins to talk about right versus wrong and who decides. ['Why can you all take such a stupid and uninformed attitude to ethics?']
# --------
# 11 [11 11] Tyler's friends are all obnoxious, he's a bad kid
# ALL teenagers are irresponsible She has always associated with shady people, so she must not be trustworthy.
# --------
# 0 [11  6] (1) William Dembski argues that modern biology supports the idea that there is an intelligent designer who created life. (2) Dembski would say that because he’s religious. Therefore: (3) Modern biology doesn’t support intelligent design
# Religion may have been wrong about a few things, but science has been wrong about many more things! Ted: Biological evolution is both a theory and a fact. Edwin: That is ridiculous! How can you possibly be absolutely certain that we evolved from pond scum! Ted: Actually, that is a gross misrepresentation of my assertion. I never claimed we evolved from pond scum.
# --------
# 11 [1 1] "Annie must like Starbucks because all white girls like Starbucks."
# "Everyone should like coffee: 95% of teachers do!" Everyone I know is making fruit smoothies for quick, portable meals, so smoothies must be really good for you.
# --------
# 11 [7 7] French people are great at kissing. Julie is French. Get me a date!
# ['"We really like girls, so they should get married."'] ['"We both adore them, so they should get married."']
# --------
# 2 [6 4] This technique using vague positive words that actually hold little meaning.
# Misrepresents the context from which a quotation is taken; putting words or ideas in people’s mouth/head; creating a “dummy” or fake or falsified argument or situation so you can attack it. The writer or speaker intentionally misleads the audience by using a word with a double or ambiguous meaning.
# --------
# 8 [11  8] That parking attendant who gave me a ticket is as bad as Hitler.
# That German, Fred, stole my wallet. All Germans are thieves. This dress code is so bad I feel like I'm in prison.
# --------
# 5 [ 7 11] We're going to celebrate New Year's Eve this way because that's how we've always done it.
# ['"We all like music, so we always get together'] Don't let your children stay up till midnight on New Year's Eve. Before you know it, they'll be demanding to stay up till midnight every night.
# --------
# 12 [12  1] Because you found something difficult to understand, or are unaware of how it works, you made out like it is probably not true.
# Superstition is a belief or practice resulting from ignorance, fear of the unknown, trust in magic or chance, or a false conception of causation -- unless it is astrology. ['Get why other people may be wrong.']
# --------
# 5 [5 5] Dave: For five generations, the men in our family went to Stanford and became doctors, while the women got married and raised children.  Therefore, it is my duty to become a doctor. Kaitlin: Do you want to become a doctor? Dave: It doesn’t matter -- it is our family tradition.  Who am I to break it?
# Our family has always been farmers, so we should always be farmers Everyone in our family has gone to the University of Tennessee, so you need to apply to UT.
# --------
# 10 [12  7] If it wasn't a missile, a bomb, or mechanical failure, then all that's left is a meteorite.
# We haven’t proven aliens didn’t create life on earth, so aliens created life on earth. It is possible aliens built the pyramids. Therefore, aliens built the pyramids.
# --------
# 7 [1 1] I believe that PNoy is the Abraham Lincoln of the Philippines.
# Lahat nakamove-on na ikaw na lang hindi pa. #MarcosIsAHero Trump cites (biased) poll results showing that people think he’s a strong leader to prove a point that he is a strong leader. ABC News/Washington Post Poll (wrong big on election) said almost all stand by their vote on me & 53% said strong leader.
# --------
# 11 [1 1] Everyone who gets a college degree is better off.  All people who are better off as a result of getting a degree are good to have conversations with.  Therefore, everyone who gets a college degree is a good person to have a conversation with.
# Everybody does it.  You should too. , if everyone else is doing something, it must be right/good.
# --------
# 2 [2 2] “I know the exam is graded based on performance, but you should give me an A. My cat has been sick, my car broke down, and I’ve had a cold, so it was really hard for me to study!”
# "I should receive an 'A' in this class. I had a tough week!" Hadi begged Professor, you have to give me an A on this paper. I know I only turned in a sentence and some clip art, but you have to understand, my grandmother suddenly died while traveling in the Northern Yukon, and her funeral was there so I had to travel, and my parents got divorced in the middle of the ceremony, and all the stress caused me to become catatonic for two weeks. Have some pity — my grandmother's last wish was that I'd get an A in this class.
# --------
# 6 [ 1 10] Those who believe in behavior modification obviously want to try to control everyone by subjecting them to rewards and punishments.
# This persuasive technique is used to make you feel left out if you don't join the group. Force people to choose between two extreme choices intentionally ignoring the whole spectrum of other possibilities.
# --------
# 0 [10 10] After Sally presents an eloquent and compelling case for a more equitable taxation system, Sam asks the audience whether we should believe anything from a woman who isn't married, was once arrested, and smells a bit weird.
# ['At a recent cocktail party, the talk has drifted to family life, and your wife asked you “Are you a cat or or dog person?"'] ['At the holiday cocktail party, the conversation has moved to family pets, and your wife questions you are you a cat or a dog person?"']
# --------
# 2 [2 2] I really deserve an “A” on this paper, professor.  Not only did I study during my grandmother’s funeral, but I also passed up the heart transplant surgery, even though that was the first matching donor in 3 years.
# You have to give me a passing grade. I spent 150 hours on that project and missed every party this quarter. I should receive an 'A' in this class. After all, if I don't get an 'A' I won't get the fellowship that I want.
# --------
# 7 [5 5] Smoking cigarettes is just like ingesting arsenic into your system; both have been shown to be causally related to death. If you wouldn't want to take a spoonful of arsenic, I would think that you wouldn't want to continue smoking.
# ['There are definitely a connection between smoking and drinking energy drinks. I read about it through Wikipedia.'] ['There is definitely a connection between smoking and drinking mixed drinks. I read on it on Wikipedia.']
# --------
# 0 [0 0] Says Robot 2, attacking Robot 1 instead of his arguments.
# “against the man;” attacking the individual rather than their position. person 1 : "We should argue with logic facts" person 2: "You should grow a brain before you open your mouth"
# --------
# 2 [2 9] Sometimes kids ride skateboards and fall off, breaking their arms or legs. Clearly, riding a skateboard is extremely dangerous. Don’t you think skateboards should be banned?
# Children should not go trick or treating, as there always exists the possibility that someone could poison the treats. Children who play violent video games act more violently than those who don’t.
# --------
