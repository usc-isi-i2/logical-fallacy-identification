# %%
import requests


def make_request(query):
    base_url = "http://api.conceptnet.io"
    if not query.startswith(base_url):
        query = f"{base_url}{query}"
    return requests.get(query).json()

def read_edges(obj):
    for edge in obj['edges']:
        if edge['start']['language'] == 'en' and edge['end']['language'] == 'en':
            yield {
                'edge': (edge['start']['label'], edge['rel']['label'], edge['end']['label']),
                'example': edge['surfaceText']
            }

def get_relations_between_words(word1, word2):
    word1 = word1.replace(' ', '_')
    word2 = word2.replace(' ', '_')
    query = f"/query?node=/c/en/{word1}&other=/c/en/{word2}&language=en"
    obj = make_request(query=query)
    edges = list(read_edges(obj))
    return edges

def get_edges_related_to_word(word):
    word = word.replace(' ', '_')
    query = f"/query?node=/c/en/{word}&language=en"
    obj = make_request(query = query)
    edges = list(read_edges(obj))
    return edges

# %%
import re

import joblib
import pandas as pd
from tqdm import tqdm

# %%
dump = pd.read_csv("data/kgtk_conceptnet.tsv", sep = "\t")

dump.drop(columns=['relation;dimension', 'source'], inplace=True, axis = 1)

pattern = r"/c/en/([^/]*)(/.*)?"

from collections import defaultdict

label_dict = dict()
rel_dict = defaultdict(set)

for _, row in tqdm(dump.iterrows(), leave = False):
    node1 = row['node1']
    node2 = row['node2']

    rel = row['relation;label']
    sent = row['sentence']

    node1_id = re.match(pattern, node1).group(1)
    node2_id = re.match(pattern, node2).group(1)

    node1_label = row['node1;label']
    node2_label = row['node2;label']
    
    label_dict[node1_id] = node1_label
    label_dict[node2_id] = node2_label

    rel_dict[(node1_id, node2_id)].add((rel, sent))


import joblib

joblib.dump(rel_dict, "data/conceptNet_relations.joblib")
joblib.dump(label_dict, "data/conceptNet_labels.joblib")
# Out:
# /tmp/ipykernel_3913714/3493011625.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dump = pd.read_csv("data/kgtk_conceptnet.tsv", sep = "\t")

# %%
dump = pd.read_csv("data/kgtk_conceptnet.tsv", sep = "\t")
# Out:
# /tmp/ipykernel_827565/1824619749.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dump = pd.read_csv("data/kgtk_conceptnet.tsv", sep = "\t")

# %%
dump.head(3)
# Out:
#                    node1    relation                node2    node1;label  \
# 0              /c/en/0/n  /r/Antonym              /c/en/1              0
# 1  /c/en/12_hour_clock/n  /r/Antonym  /c/en/24_hour_clock  12 hour clock
# 2  /c/en/24_hour_clock/n  /r/Antonym  /c/en/12_hour_clock  24 hour clock
#
#      node2;label relation;label  relation;dimension source sentence
# 0              1        antonym                 NaN     CN      NaN
# 1  24 hour clock        antonym                 NaN     CN      NaN
# 2  12 hour clock        antonym                 NaN     CN      NaN

# %%
dump.shape
# Out:
# (3423004, 9)

# %%
import consts

# %%
good_relations_labels = dump[dump['relation'].isin(consts.good_relations)]['relation;label'].unique().tolist()

# %%
good_relations_labels
# Out:
# ['at location',
#  'capable of',
#  'causes',
#  'causes desire',
#  'desires',
#  'has first subevent',
#  'has last subevent',
#  'has property',
#  'is a',
#  'located near',
#  'made of',
#  'part of',
#  'symbol of',
#  'used for']

# %%
dump[dump['relation'].isin(consts.good_relations)].shape
# Out:
# (373389, 9)

# %%
rel_dict = joblib.load("data/conceptNet_relations.joblib")
label_dict = joblib.load("data/conceptNet_labels.joblib")

# %%
rel_dict
# Out:
# defaultdict(set,
#             {('0', '1'): {('antonym', nan), ('related to', nan)},
#              ('12_hour_clock', '24_hour_clock'): {('antonym', nan)},
#              ('24_hour_clock', '12_hour_clock'): {('antonym', nan)},
#              ('5', '3'): {('antonym', nan)},
#              ('a.c', 'd.c'): {('antonym', nan)},
#              ('a.m', 'afternoon'): {('antonym', nan)},
#              ('a.m', 'p.m'): {('antonym', nan), ('distinct from', nan)},
#              ('a.m', 'pm'): {('antonym', nan), ('distinct from', nan)},
#              ('ab_extra', 'ab_intra'): {('antonym', nan)},
#              ('ab_intra', 'ab_extra'): {('antonym', nan)},
#              ('abactinal', 'actinal'): {('antonym', nan)},
#              ('abandon', 'acquire'): {('antonym', nan)},
#              ('abandon', 'arrogate'): {('antonym', nan)},
#              ('abandon', 'embrace'): {('antonym', nan)},
#              ('abandon', 'engage'): {('antonym', nan)},
#              ('abandon', 'gain'): {('antonym', nan)},
#              ('abandon', 'join'): {('antonym', nan)},
#              ('abandon', 'maintain'): {('antonym', nan)},
#              ('abandon', 'retain'): {('antonym', nan)},
#              ('abandon', 'unite'): {('antonym', nan)},
#              ('abandonment', 'acquisition'): {('antonym', nan)},
#              ('abapical', 'apical'): {('antonym', nan)},
#              ('abase', 'exalt'): {('antonym', nan)},
#              ('abash', 'embolden'): {('antonym', nan)},
#              ('abash', 'reassure'): {('antonym', nan)},
#              ('abate', 'augment'): {('antonym', nan)},
#              ('abaxial', 'adaxial'): {('antonym', nan)},
#              ('abaxonal', 'adaxonal'): {('antonym', nan)},
#              ('abbreviate', 'lengthen'): {('antonym', nan)},
#              ('abderian', 'agelastic'): {('antonym', nan)},
#              ('abducent', 'adducent'): {('antonym', nan)},
#              ('abduction', 'adduction'): {('antonym', nan)},
#              ('abductive', 'deduce'): {('antonym', nan)},
#              ('abductor', 'abductee'): {('antonym', nan)},
#              ('abductor', 'adductor'): {('antonym', nan)},
#              ('abideable', 'insupportable'): {('antonym', nan)},
#              ('abideable', 'intolerable'): {('antonym', nan)},
#              ('abideable', 'unabideable'): {('antonym', nan)},
#              ('abideable', 'unbearable'): {('antonym', nan)},
#              ('abience', 'adience'): {('antonym', nan)},
#              ('abient', 'adient'): {('antonym', nan)},
#              ('ability', 'disability'): {('antonym', nan),
#               ('related to', nan)},
#              ('ability', 'inability'): {('antonym', nan)},
#              ('abiogenesis', 'biogenesis'): {('antonym', nan)},
#              ('abiogenesis', 'transformism'): {('antonym', nan)},
#              ('abjectly', 'proudly'): {('antonym', nan)},
#              ('abjugate', 'adjugate'): {('antonym', nan)},
#              ('able',
#               'cane'): {('antonym', '[[able]] is the opposite of [[cane]]')},
#              ('able',
#               'cannot'): {('antonym',
#                '[[able]] is the opposite of [[cannot]]'),
#               ('related to', '[[able]] is related to [[cannot]]')},
#              ('able',
#               'disability'): {('antonym',
#                '[[able]] is the opposite of [[disability]]')},
#              ('able', 'unable'): {('antonym', nan)},
#              ('abled', 'disabled'): {('antonym', nan)},
#              ('abluminal', 'adluminal'): {('antonym', nan)},
#              ('abnormal', 'normal'): {('antonym', nan), ('related to', nan)},
#              ('abnormality', 'normality'): {('antonym', nan)},
#              ('abolish', 'establish'): {('antonym', nan)},
#              ('abolition', 'establishment'): {('antonym', nan)},
#              ('aborad', 'orad'): {('antonym', nan), ('derived from', nan)},
#              ('abortionist', 'anti_abortionist'): {('antonym', nan)},
#              ('about',
#               'precisely'): {('antonym',
#                '[[about]] is the opposite of [[precisely]]')},
#              ('above',
#               'below'): {('antonym',
#                '[[above]] is the opposite of [[below]]'), ('distinct from',
#                '[[above]] is not [[below]]'), ('related to',
#                '[[above]] is related to [[below]]')},
#              ('above_average', 'below_average'): {('antonym', nan)},
#              ('above_fold', 'below_fold'): {('antonym', nan)},
#              ('above_fold', 'below_scroll'): {('antonym', nan)},
#              ('above_mentioned', 'following'): {('antonym', nan)},
#              ('above_mentioned', 'undermentioned'): {('antonym', nan)},
#              ('above_par', 'below_par'): {('antonym', nan)},
#              ('above_salt', 'below_salt'): {('antonym', nan)},
#              ('above_water', 'under_water'): {('antonym', nan)},
#              ('aboveground', 'belowground'): {('antonym', nan)},
#              ('aboveground', 'underground'): {('antonym', nan),
#               ('related to', nan)},
#              ('aboveness', 'belowness'): {('antonym', nan)},
#              ('abridgable', 'unabridgable'): {('antonym', nan)},
#              ('abrogate', 'establish'): {('antonym', nan)},
#              ('abrogate', 'fix'): {('antonym', nan)},
#              ('abrogate', 'promulgate'): {('antonym', nan)},
#              ('abruptly_pinnate', 'imparipinnate'): {('antonym', nan)},
#              ('abruptly_pinnate', 'odd_pinnate'): {('antonym', nan)},
#              ('absence', 'existence'): {('antonym', nan)},
#              ('absence', 'presence'): {('antonym', nan)},
#              ('absence_makes_heart_grow_fonder',
#               'long_absent_soon_forgotten'): {('antonym', nan)},
#              ('absence_makes_heart_grow_fonder',
#               'out_of_sight_out_of_mind'): {('antonym', nan)},
#              ('absence_makes_heart_grow_fonder',
#               "when_cat's_away_mice_will_play"): {('antonym', nan)},
#              ('absent', 'present'): {('antonym', nan), ('related to', nan)},
#              ('absolute', 'conditional'): {('antonym', nan)},
#              ('absolute', 'relative'): {('antonym', nan), ('related to', nan)},
#              ('absolute_majority', 'plurality'): {('antonym', nan)},
#              ('absolute_majority', 'relative_majority'): {('antonym', nan)},
#              ('absoluteness', 'conditionality'): {('antonym', nan)},
#              ('absoluteness', 'limitedness'): {('antonym', nan)},
#              ('absoluteness', 'relativity'): {('antonym', nan)},
#              ('absolutism', 'relativism'): {('antonym', nan)},
#              ('absolutist', 'relativist'): {('antonym', nan)},
#              ('absolvitor', 'condemnator'): {('antonym', nan)},
#              ('absonant', 'consonant'): {('antonym', nan)},
#              ('absorb', 'emit'): {('antonym', nan)},
#              ('abstemious', 'immoderate'): {('antonym', nan)},
#              ('abstract', 'applied'): {('antonym', nan)},
#              ('abstract', 'concrete'): {('antonym', nan), ('related to', nan)},
#              ('abstract_class', 'concrete_class'): {('antonym', nan)},
#              ('abstract_method', 'concrete_method'): {('antonym', nan)},
#              ('abstract_noun', 'concrete_noun'): {('antonym', nan)},
#              ('abstract_number', 'concrete_number'): {('antonym', nan)},
#              ('abstract_verb', 'concrete_verb'): {('antonym', nan)},
#              ('abstract_verb', 'definite_verb'): {('antonym', nan)},
#              ('abstract_verb', 'determinate_verb'): {('antonym', nan)},
#              ('abstraction', 'concretization'): {('antonym', nan)},
#              ('abstraction', 'specialization'): {('antonym', nan)},
#              ('abstractness', 'concreteness'): {('antonym', nan)},
#              ('abundance',
#               'few'): {('antonym',
#                '[[abundance]] is the opposite of [[few]]'), ('distinct from',
#                '[[abundance]] is not [[few]]')},
#              ('abundant', 'rare'): {('antonym', nan)},
#              ('abundant', 'scarce'): {('antonym', nan)},
#              ('abvalvar', 'advalvar'): {('antonym', nan)},
#              ('ac', 'ad'): {('antonym', nan), ('synonym', nan)},
#              ('ac', 'dc'): {('antonym', nan)},
#              ('academically', 'non_academically'): {('antonym', nan)},
#              ('acapnia', 'hypercapnia'): {('antonym', nan)},
#              ('accede', 'leave'): {('antonym', nan)},
#              ('accelerate', 'decelerate'): {('antonym', nan)},
#              ('accelerate', 'retard'): {('antonym', nan)},
#              ('accelerate', 'unaccelerate'): {('antonym', nan)},
#              ('acceleration', 'deceleration'): {('antonym', nan),
#               ('distinct from', nan),
#               ('related to', nan)},
#              ('accept',
#               'decline'): {('antonym',
#                '[[accept]] is the opposite of [[decline]]'), ('antonym',
#                nan), ('distinct from', nan)},
#              ('accept',
#               'deny'): {('antonym', '[[accept]] is the opposite of [[deny]]')},
#              ('accept',
#               'refuse'): {('antonym',
#                '[[accept]] is the opposite of [[refuse]]'),
#               ('distinct from', nan)},
#              ('accept',
#               'reject'): {('antonym',
#                '[[accept]] is the opposite of [[reject]]'), ('antonym',
#                nan), ('distinct from', '[[accept]] is not [[reject]]'), ('distinct from',
#                nan)},
#              ('acceptability', 'inacceptability'): {('antonym', nan)},
#              ('acceptability', 'unacceptability'): {('antonym', nan)},
#              ('acceptable', 'inacceptable'): {('antonym', nan)},
#              ('acceptable', 'unacceptable'): {('antonym', nan)},
#              ('accessible', 'inaccessible'): {('antonym', nan)},
#              ('accession', 'deaccession'): {('antonym', nan)},
#              ('accessor', 'mutator'): {('antonym', nan)},
#              ('accident',
#               'on_purpose'): {('antonym',
#                '[[accident]] is the opposite of [[on purpose]]')},
#              ('accident',
#               'planned'): {('antonym',
#                '[[accident]] is the opposite of [[planned]]')},
#              ('accident',
#               'purpose'): {('antonym',
#                '[[accident]] is the opposite of [[purpose]]')},
#              ('accidentally', 'intentionally'): {('antonym', nan)},
#              ('acclivity', 'declivity'): {('antonym', nan),
#               ('related to', nan)},
#              ('acclivous', 'declivous'): {('antonym', nan)},
#              ('accommodate', 'discommodate'): {('antonym', nan)},
#              ('accountable', 'unaccountable'): {('antonym', nan)},
#              ('accountably', 'irresponsibly'): {('antonym', nan)},
#              ('accountably', 'unaccountably'): {('antonym', nan)},
#              ('accretion', 'attrition'): {('antonym', nan)},
#              ('accretion', 'decay'): {('antonym', nan)},
#              ('accretion', 'erosion'): {('antonym', nan)},
#              ('accrue', 'amortize'): {('antonym', nan)},
#              ('accumulation', 'decumulation'): {('antonym', nan)},
#              ('accumulation_point', 'isolated_point'): {('antonym', nan)},
#              ('accuracy', 'inaccuracy'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('accurate', 'inaccurate'): {('antonym', nan)},
#              ('accurateness', 'inaccurateness'): {('antonym', nan)},
#              ('accusatorial', 'inquisitorial'): {('antonym', nan)},
#              ('acerebral', 'cerebral'): {('antonym', nan),
#               ('derived from', nan)},
#              ('achieved_status', 'ascribed_status'): {('antonym', nan)},
#              ('achiral', 'chiral'): {('antonym', nan), ('derived from', nan)},
#              ('acholia', 'cholaemia'): {('antonym', nan)},
#              ('acid', 'alkaline'): {('antonym', nan), ('distinct from', nan)},
#              ('acid', 'base'): {('antonym', nan), ('related to', nan)},
#              ('acid', 'alkali'): {('antonym', nan)},
#              ('acidic', 'basic'): {('antonym', nan), ('related to', nan)},
#              ('acidify', 'alkalify'): {('antonym', nan)},
#              ('acidify', 'basify'): {('antonym', nan)},
#              ('acidity', 'alkalinity'): {('antonym', nan)},
#              ('ack', 'nak'): {('antonym', nan)},
#              ('ack', 'nack'): {('antonym', nan)},
#              ('acme', 'nadir'): {('antonym', nan)},
#              ('acoloutha', 'anacoloutha'): {('antonym', nan)},
#              ('acoptic', 'coptic'): {('antonym', nan)},
#              ('acoptic', 'nonacoptic'): {('antonym', nan)},
#              ('acquire', 'abandon'): {('antonym', nan)},
#              ('acquisition', 'abandonment'): {('antonym', nan)},
#              ('acquittal', 'condemnation'): {('antonym', nan)},
#              ('acquittal', 'conviction'): {('antonym', nan)},
#              ('acrimonious', 'nonacrimonious'): {('antonym', nan)},
#              ('acrimony', 'friendship'): {('antonym', nan)},
#              ('acrimony', 'peace'): {('antonym', nan)},
#              ('acrogynous', 'anacrogynous'): {('antonym', nan)},
#              ('acronycal', 'cosmical'): {('antonym', nan)},
#              ('acropetal', 'basipetal'): {('antonym', nan)},
#              ('acrophase', 'bathyphase'): {('antonym', nan)},
#              ('acrophase', 'trough'): {('antonym', nan)},
#              ('acrophobia', 'bathophobia'): {('antonym', nan)},
#              ('acrophyll', 'bathyphyll'): {('antonym', nan)},
#              ('acroscopic', 'basiscopic'): {('antonym', nan)},
#              ('across',
#               'crossword'): {('antonym',
#                '[[across]] is the opposite of [[crossword]]'), ('related to',
#                '[[across]] is related to [[crossword]]')},
#              ('across',
#               'crossword_down'): {('antonym',
#                '[[across]] is the opposite of [[crossword down]]')},
#              ('across',
#               'down'): {('antonym',
#                '[[across]] is the opposite of [[down]]'), ('distinct from',
#                '[[across]] is not [[down]]')},
#              ('across',
#               'parallel'): {('antonym',
#                '[[across]] is the opposite of [[parallel]]')},
#              ('across_variable', 'through_variable'): {('antonym', nan)},
#              ('act',
#               'be_real'): {('antonym',
#                '[[act]] is the opposite of [[be real]]')},
#              ('act', 'do'): {('antonym', '[[act]] is the opposite of [[do]]'),
#               ('related to', '[[act]] is related to [[do]]')},
#              ('act',
#               'do_nothing'): {('antonym',
#                '[[act]] is the opposite of [[do nothing]]')},
#              ('act',
#               'nothing'): {('antonym',
#                '[[act]] is the opposite of [[nothing]]')},
#              ('act',
#               'real'): {('antonym', '[[act]] is the opposite of [[real]]')},
#              ('actifan', 'passifan'): {('antonym', nan)},
#              ('action', 'inaction'): {('antonym', nan)},
#              ('actions_speak_louder_than_words',
#               'pen_is_mightier_than_sword'): {('antonym', nan)},
#              ('activate', 'deactivate'): {('antonym', nan)},
#              ('activate', 'disactivate'): {('antonym', nan)},
#              ('activate', 'inactivate'): {('antonym', nan)},
#              ('active', 'inactive'): {('antonym', nan)},
#              ('active_duty', 'reserve'): {('antonym', nan),
#               ('related to', nan)},
#              ('activity', 'inactivity'): {('antonym', nan)},
#              ('activity', 'passivity'): {('antonym', nan)},
#              ('activity', 'rest'): {('antonym', nan)},
#              ('actual',
#               'fake'): {('antonym', '[[actual]] is the opposite of [[fake]]'),
#               ('distinct from', '[[actual]] is not [[fake]]')},
#              ('actual',
#               'fake_simulated'): {('antonym',
#                '[[actual]] is the opposite of [[fake simulated]]')},
#              ('actual',
#               'pretend'): {('antonym',
#                '[[actual]] is the opposite of [[pretend]]')},
#              ('actual',
#               'simulated'): {('antonym',
#                '[[actual]] is the opposite of [[simulated]]')},
#              ('actual',
#               'smaller'): {('antonym',
#                '[[actual]] is the opposite of [[smaller]]')},
#              ('actual', 'future'): {('antonym', nan)},
#              ('actual', 'potential'): {('antonym', nan)},
#              ('acute_toxicity', 'chronic_toxicity'): {('antonym', nan)},
#              ('acyanophilous', 'cyanophilous'): {('antonym', nan),
#               ('derived from', nan)},
#              ('acyclic', 'cyclic'): {('antonym', nan),
#               ('derived from', nan),
#               ('related to', nan)},
#              ('ad', 'bc'): {('antonym', nan)},
#              ('ad', 'ac'): {('antonym', nan), ('synonym', nan)},
#              ('ad_hominem', 'ad_verecundiam'): {('antonym', nan)},
#              ('ad_hominem', 'appeal_to_authority'): {('antonym', nan)},
#              ('ad_hominem', 'ipse_dixit'): {('antonym', nan)},
#              ('adam_teasing', 'eve_teasing'): {('antonym', nan)},
#              ('adapical', 'adbasal'): {('antonym', nan)},
#              ('adaptive', 'maladaptive'): {('antonym', nan)},
#              ('adaxial', 'abaxial'): {('antonym', nan)},
#              ('adaxonal', 'abaxonal'): {('antonym', nan)},
#              ('adbasal', 'adapical'): {('antonym', nan)},
#              ('add',
#               'subtract'): {('antonym',
#                '[[add]] is the opposite of [[subtract]]'), ('antonym',
#                nan), ('distinct from', '[[add]] is not [[subtract]]'), ('related to',
#                '[[add]] is related to [[subtract]]')},
#              ('add',
#               'subtraction'): {('antonym',
#                '[[add]] is the opposite of [[subtraction]]'), ('distinct from',
#                '[[add]] is not [[subtraction]]')},
#              ('add',
#               'take'): {('antonym', '[[add]] is the opposite of [[take]]')},
#              ('add',
#               'take_away'): {('antonym',
#                '[[add]] is the opposite of [[take away]]')},
#              ('add', 'remove'): {('antonym', nan), ('distinct from', nan)},
#              ('adder',
#               'subtract'): {('antonym',
#                '[[adder]] is the opposite of [[subtract]]')},
#              ('addibility', 'inaddibility'): {('antonym', nan)},
#              ('addible', 'inaddible'): {('antonym', nan)},
#              ('addicting', 'nonaddictive'): {('antonym', nan)},
#              ('addictive', 'nonaddictive'): {('antonym', nan)},
#              ('addition',
#               'subtraction'): {('antonym',
#                '[[addition]] is the opposite of [[subtraction]]'), ('antonym',
#                nan), ('related to', nan)},
#              ('addition', 'deduction'): {('antonym', nan)},
#              ('addition', 'exclusion'): {('antonym', nan)},
#              ('addressable', 'unaddressable'): {('antonym', nan)},
#              ('addressee', 'sender'): {('antonym', nan)},
#              ('addressee', 'speaker'): {('antonym', nan)},
#              ('adept', 'inept'): {('antonym', nan)},
#              ('adequate', 'inadequate'): {('antonym', nan)},
#              ('adfix', 'infix'): {('antonym', nan)},
#              ('adhesion', 'cohesion'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('adiabatic', 'diabatic'): {('antonym', nan)},
#              ('adiabatic', 'nonadiabatic'): {('antonym', nan)},
#              ('adjacent', 'apart'): {('antonym', nan)},
#              ('adjectival_pronoun',
#               'substantival_pronoun'): {('antonym', nan)},
#              ('adjoining', 'separated'): {('antonym', nan)},
#              ('adluminal', 'abluminal'): {('antonym', nan)},
#              ('administrative', 'non_administrative'): {('antonym', nan)},
#              ('admire',
#               'despise'): {('antonym',
#                '[[admire]] is the opposite of [[despise]]')},
#              ('admissibility', 'inadmissibility'): {('antonym', nan)},
#              ('admissible', 'inadmissible'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('admit',
#               'deny'): {('antonym', '[[admit]] is the opposite of [[deny]]')},
#              ('admit',
#               'reject'): {('antonym',
#                '[[admit]] is the opposite of [[reject]]')},
#              ('admittable', 'unadmittable'): {('antonym', nan)},
#              ('adnate', 'connate'): {('antonym', nan)},
#              ('adonist', 'jehovist'): {('antonym', nan)},
#              ('adopt',
#               'abandon'): {('antonym',
#                '[[adopt]] is the opposite of [[abandon]]')},
#              ('adopt',
#               'biological'): {('antonym',
#                '[[adopt]] is the opposite of [[biological]]')},
#              ('adopt',
#               'biological_child'): {('antonym',
#                '[[adopt]] is the opposite of [[biological child]]')},
#              ('adopt',
#               'birth'): {('antonym',
#                '[[adopt]] is the opposite of [[birth]]'), ('distinct from',
#                '[[adopt]] is not [[birth]]')},
#              ('adopt',
#               'child'): {('antonym',
#                '[[adopt]] is the opposite of [[child]]'), ('related to',
#                '[[adopt]] is related to [[child]]')},
#              ('adopt',
#               'children'): {('antonym',
#                '[[adopt]] is the opposite of [[children]]'), ('related to',
#                '[[adopt]] is related to [[children]]')},
#              ('adopt',
#               'give'): {('antonym', '[[adopt]] is the opposite of [[give]]')},
#              ('adopt',
#               'give_away'): {('antonym',
#                '[[adopt]] is the opposite of [[give away]]')},
#              ('adopt',
#               'orphan'): {('antonym',
#                '[[adopt]] is the opposite of [[orphan]]'), ('related to',
#                '[[adopt]] is related to [[orphan]]')},
#              ('adopt',
#               'own'): {('antonym', '[[adopt]] is the opposite of [[own]]')},
#              ('adopt',
#               'own_children'): {('antonym',
#                '[[adopt]] is the opposite of [[own children]]')},
#              ('adoration', 'disdain'): {('antonym', nan)},
#              ('adore', 'disdain'): {('antonym', nan)},
#              ('adret', 'ubac'): {('antonym', nan)},
#              ('adroit', 'clumsy'): {('antonym', nan)},
#              ('adroit', 'maladroit'): {('antonym', nan)},
#              ('adsorbent', 'nonadsorbent'): {('antonym', nan)},
#              ('adsorption', 'desorption'): {('antonym', nan)},
#              ('adsorptive', 'nonadsorptive'): {('antonym', nan)},
#              ('adult',
#               'child'): {('antonym',
#                '[[adult]] is the opposite of [[child]]'), ('distinct from',
#                '[[adult]] is not [[child]]'), ('related to',
#                '[[adult]] is related to [[child]]')},
#              ('adulteration', 'purification'): {('antonym', nan)},
#              ('adulthood', 'childhood'): {('antonym', nan)},
#              ('adultish', 'childish'): {('antonym', nan)},
#              ('advalvar', 'abvalvar'): {('antonym', nan)},
#              ('advance',
#               'backward'): {('antonym',
#                '[[advance]] is the opposite of [[backward]]')},
#              ('advance',
#               'basic'): {('antonym',
#                '[[advance]] is the opposite of [[basic]]')},
#              ('advance',
#               'going'): {('antonym',
#                '[[advance]] is the opposite of [[going]]'), ('related to',
#                '[[advance]] is related to [[going]]')},
#              ('advance',
#               'going_backward'): {('antonym',
#                '[[advance]] is the opposite of [[going backward]]')},
#              ('advance',
#               'late'): {('antonym',
#                '[[advance]] is the opposite of [[late]]')},
#              ('advance',
#               'late_payment'): {('antonym',
#                '[[advance]] is the opposite of [[late payment]]')},
#              ('advance',
#               'payment'): {('antonym',
#                '[[advance]] is the opposite of [[payment]]'), ('related to',
#                '[[advance]] is related to [[payment]]')},
#              ('advance',
#               'retreat'): {('antonym',
#                '[[advance]] is the opposite of [[retreat]]'), ('distinct from',
#                '[[advance]] is not [[retreat]]')},
#              ('advantage',
#               'con'): {('antonym',
#                '[[advantage]] is the opposite of [[con]]')},
#              ('advantage',
#               'handicap'): {('antonym',
#                '[[advantage]] is the opposite of [[handicap]]')},
#              ('advantage', 'disadvantage'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('advantageously', 'disadvantageously'): {('antonym', nan)},
#              ('advehent', 'revehent'): {('antonym', nan)},
#              ('adventure',
#               'boring'): {('antonym',
#                '[[adventure]] is the opposite of [[boring]]')},
#              ('adventure',
#               'lazy'): {('antonym',
#                '[[adventure]] is the opposite of [[lazy]]')},
#              ('adventure', 'abstention'): {('antonym', nan)},
#              ('adventurous', 'nervous'): {('antonym', nan)},
#              ('adventurous', 'safe'): {('antonym', nan)},
#              ('adverb',
#               'adjective'): {('antonym',
#                '[[adverb]] is the opposite of [[adjective]]'), ('distinct from',
#                '[[adverb]] is not [[adjective]]'), ('related to',
#                '[[adverb]] is related to [[adjective]]'), ('related to', nan)},
#              ('adverb',
#               'pronoun'): {('antonym',
#                '[[adverb]] is the opposite of [[pronoun]]')},
#              ('adversarial', 'cooperative'): {('antonym', nan)},
#              ('adverse_effect', 'desired_effect'): {('antonym', nan)},
#              ('advertent', 'inadvertent'): {('antonym', nan),
#               ('related to', nan)},
#              ('advisability', 'inadvisability'): {('antonym', nan)},
#              ('advisory', 'mandatory'): {('antonym', nan)},
#              ('aequihymeniiferous',
#               'inaequihymeniiferous'): {('antonym', nan)},
#              ('aerobic', 'anaerobic'): {('antonym', nan)},
#              ('aerobiosis', 'anaerobiosis'): {('antonym', nan)},
#              ('aerobiotic', 'nonaerobiotic'): {('antonym', nan)},
#              ('aerodyne', 'aerostat'): {('antonym', nan)},
#              ('aerophyte', 'anaerophyte'): {('antonym', nan)},
#              ('aerostat', 'aerodyne'): {('antonym', nan), ('related to', nan)},
#              ('aesthetical', 'inaesthetic'): {('antonym', nan)},
#              ('aestival', 'brumal'): {('antonym', nan)},
#              ('aestival', 'hibernal'): {('antonym', nan)},
#              ('aff', 'neg'): {('antonym', nan)},
#              ('affair',
#               'activity'): {('antonym',
#                '[[affair]] is the opposite of [[activity]]'), ('related to',
#                '[[affair]] is related to [[activity]]')},
#              ('affair',
#               'faithful'): {('antonym',
#                '[[affair]] is the opposite of [[faithful]]')},
#              ('affair',
#               'faithful_activity'): {('antonym',
#                '[[affair]] is the opposite of [[faithful activity]]')},
#              ('affair',
#               'fidelity'): {('antonym',
#                '[[affair]] is the opposite of [[fidelity]]')},
#              ('affair',
#               'loyal'): {('antonym',
#                '[[affair]] is the opposite of [[loyal]]')},
#              ('affair',
#               'marriage'): {('antonym',
#                '[[affair]] is the opposite of [[marriage]]'), ('related to',
#                '[[affair]] is related to [[marriage]]')},
#              ('affair',
#               'relationship'): {('antonym',
#                '[[affair]] is the opposite of [[relationship]]'), ('related to',
#                '[[affair]] is related to [[relationship]]')},
#              ('afferent', 'efferent'): {('antonym', nan)},
#              ('afferently', 'efferently'): {('antonym', nan)},
#              ('affinal', 'consanguine'): {('antonym', nan)},
#              ('affirm', 'deny'): {('antonym', nan)},
#              ('affirmative', 'negative'): {('antonym', nan),
#               ('related to', nan)},
#              ('affix', 'nonaffix'): {('antonym', nan)},
#              ('affluence', 'indigence'): {('antonym', nan),
#               ('etymologically related to', nan)},
#              ('affluent', 'indigent'): {('antonym', nan)},
#              ('afford',
#               'expensive'): {('antonym',
#                '[[afford]] is the opposite of [[expensive]]')},
#              ('afford',
#               'too'): {('antonym', '[[afford]] is the opposite of [[too]]')},
#              ('afford',
#               'too_expensive'): {('antonym',
#                '[[afford]] is the opposite of [[too expensive]]')},
#              ('affordable', 'expensive'): {('antonym', nan)},
#              ('afforest', 'deforest'): {('antonym', nan)},
#              ('afforestation', 'deforestation'): {('antonym', nan)},
#              ('aforementioned', 'following'): {('antonym', nan)},
#              ('aforementioned', 'undermentioned'): {('antonym', nan)},
#              ('aforesaid', 'following'): {('antonym', nan)},
#              ('aft', 'fore'): {('antonym', nan)},
#              ('after',
#               'before'): {('antonym',
#                '[[after]] is the opposite of [[before]]'), ('distinct from',
#                '[[after]] is not [[before]]'), ('related to',
#                '[[after]] is related to [[before]]')},
#              ('afterbear', 'forebear'): {('antonym', nan),
#               ('etymologically related to', nan)},
#              ('afterbeat', 'forebeat'): {('antonym', nan)},
#              ('afterbrain', 'forebrain'): {('antonym', nan)},
#              ('aftercoming', 'forecoming'): {('antonym', nan)},
#              ('afterdated', 'foredated'): {('antonym', nan)},
#              ('afterdeal', 'foredeal'): {('antonym', nan)},
#              ('aftergame', 'foregame'): {('antonym', nan)},
#              ('afterglow', 'foreglow'): {('antonym', nan)},
#              ('afterglow', 'hangover'): {('antonym', nan)},
#              ('afterglow', 'post_coital_tristesse'): {('antonym', nan)},
#              ('afterhand', 'beforehand'): {('antonym', nan)},
#              ('afterhand', 'forehand'): {('antonym', nan)},
#              ('afterlife', 'forelife'): {('antonym', nan)},
#              ('aftermarket', 'oem'): {('antonym', nan)},
#              ('aftername', 'forename'): {('antonym', nan)},
#              ('afternoon',
#               'before'): {('antonym',
#                '[[afternoon]] is the opposite of [[before]]'), ('related to',
#                '[[afternoon]] is related to [[before]]')},
#              ('afternoon',
#               'before_lunch'): {('antonym',
#                '[[afternoon]] is the opposite of [[before lunch]]')},
#              ('afternoon',
#               'before_noon'): {('antonym',
#                '[[afternoon]] is the opposite of [[before noon]]')},
#              ('afternoon',
#               'evening'): {('antonym',
#                '[[afternoon]] is the opposite of [[evening]]'), ('distinct from',
#                '[[afternoon]] is not [[evening]]'), ('related to',
#                '[[afternoon]] is related to [[evening]]')},
#              ('afternoon',
#               'lunch'): {('antonym',
#                '[[afternoon]] is the opposite of [[lunch]]')},
#              ('afternoon',
#               'morning'): {('antonym',
#                '[[afternoon]] is the opposite of [[morning]]'), ('distinct from',
#                '[[afternoon]] is not [[morning]]')},
#              ('afternoon',
#               'noon'): {('antonym',
#                '[[afternoon]] is the opposite of [[noon]]'), ('derived from',
#                nan)},
#              ('aftersee', 'foresee'): {('antonym', nan)},
#              ('afterset', 'foreset'): {('antonym', nan)},
#              ('aftershock', 'foreshock'): {('antonym', nan)},
#              ('aftersound', 'foresound'): {('antonym', nan)},
#              ('afterstroke', 'appoggiatura'): {('antonym', nan)},
#              ('aftertale', 'foretale'): {('antonym', nan)},
#              ('aftertest', 'foretest'): {('antonym', nan)},
#              ('afterthinker', 'forethinker'): {('antonym', nan)},
#              ('afterward', 'beforehand'): {('antonym', nan)},
#              ('afterwards', 'beforehand'): {('antonym', nan)},
#              ('again',
#               'never'): {('antonym',
#                '[[again]] is the opposite of [[never]]')},
#              ('again',
#               'once'): {('antonym',
#                '[[again]] is the opposite of [[once]]'), ('related to', '[[again]] is related to [[once]]')},
#              ('again',
#               'stop'): {('antonym', '[[again]] is the opposite of [[stop]]')},
#              ('again',
#               'stop_trying'): {('antonym',
#                '[[again]] is the opposite of [[stop trying]]')},
#              ('again',
#               'trying'): {('antonym',
#                '[[again]] is the opposite of [[trying]]')},
#              ('against',
#               'away'): {('antonym',
#                '[[against]] is the opposite of [[away]]')},
#              ('against',
#               'away_from'): {('antonym',
#                '[[against]] is the opposite of [[away from]]')},
#              ('against',
#               'being'): {('antonym',
#                '[[against]] is the opposite of [[being]]')},
#              ('against',
#               'being_for'): {('antonym',
#                '[[against]] is the opposite of [[being for]]')},
#              ('against',
#               'for'): {('antonym',
#                '[[against]] is the opposite of [[for]]'), ('distinct from', '[[against]] is not [[for]]'), ('synonym',
#                nan)},
#              ('against',
#               'for_or'): {('antonym',
#                '[[against]] is the opposite of [[for or]]'), ('related to',
#                '[[against]] is related to [[for or]]')},
#              ('against',
#               'for_someone'): {('antonym',
#                '[[against]] is the opposite of [[for someone]]')},
#              ('against',
#               'someone'): {('antonym',
#                '[[against]] is the opposite of [[someone]]')},
#              ('against',
#               'with'): {('antonym',
#                '[[against]] is the opposite of [[with]]'), ('distinct from',
#                '[[against]] is not [[with]]')},
#              ('age',
#               'getting'): {('antonym',
#                '[[age]] is the opposite of [[getting]]'), ('related to',
#                '[[age]] is related to [[getting]]')},
#              ('age',
#               'getting_younger'): {('antonym',
#                '[[age]] is the opposite of [[getting younger]]')},
#              ('age',
#               'grow'): {('antonym',
#                '[[age]] is the opposite of [[grow]]'), ('related to', '[[age]] is related to [[grow]]')},
#              ('age',
#               'grow_young'): {('antonym',
#                '[[age]] is the opposite of [[grow young]]')},
#              ('age',
#               'human'): {('antonym',
#                '[[age]] is the opposite of [[human]]'), ('related to', '[[age]] is related to [[human]]')},
#              ('age',
#               'human_years'): {('antonym',
#                '[[age]] is the opposite of [[human years]]'), ('related to',
#                '[[age]] is related to [[human years]]')},
#              ('age',
#               'number'): {('antonym',
#                '[[age]] is the opposite of [[number]]'), ('related to',
#                '[[age]] is related to [[number]]')},
#              ('age',
#               'number_years'): {('antonym',
#                '[[age]] is the opposite of [[number years]]'), ('related to',
#                '[[age]] is related to [[number years]]')},
#              ('age',
#               'old'): {('antonym',
#                '[[age]] is the opposite of [[old]]'), ('related to', '[[age]] is related to [[old]]'), ('related to',
#                nan)},
#              ('age',
#               'years'): {('antonym',
#                '[[age]] is the opposite of [[years]]'), ('related to', '[[age]] is related to [[years]]')},
#              ('age',
#               'young'): {('antonym',
#                '[[age]] is the opposite of [[young]]'), ('distinct from', '[[age]] is not [[young]]'), ('related to',
#                '[[age]] is related to [[young]]')},
#              ('age',
#               'younger'): {('antonym',
#                '[[age]] is the opposite of [[younger]]')},
#              ('age',
#               'youth'): {('antonym',
#                '[[age]] is the opposite of [[youth]]'), ('related to', '[[age]] is related to [[youth]]')},
#              ('agelastic', 'abderian'): {('antonym', nan)},
#              ('agent', 'patient'): {('antonym', nan)},
#              ('aggravate', 'mitigate'): {('antonym', nan)},
#              ('aggregant', 'antiaggregant'): {('antonym', nan)},
#              ('aggregatable', 'unaggregatable'): {('antonym', nan)},
#              ('aggregate', 'segregate'): {('antonym', nan)},
#              ('aggregation', 'disgregation'): {('antonym', nan)},
#              ('aggression', 'nonaggression'): {('antonym', nan)},
#              ('aggressive', 'passive'): {('antonym', nan)},
#              ('agile', 'unagile'): {('antonym', nan)},
#              ('agitator', 'agitatee'): {('antonym', nan)},
#              ('agnate', 'enate'): {('antonym', nan)},
#              ('agnosis', 'gnosis'): {('antonym', nan)},
#              ('ago',
#               'future'): {('antonym',
#                '[[ago]] is the opposite of [[future]]')},
#              ('agony',
#               'bliss'): {('antonym',
#                '[[agony]] is the opposite of [[bliss]]')},
#              ('agony',
#               'defeat'): {('antonym',
#                '[[agony]] is the opposite of [[defeat]]')},
#              ('agony',
#               'ecstasy'): {('antonym',
#                '[[agony]] is the opposite of [[ecstasy]]'), ('antonym', nan)},
#              ('agrammatical', 'grammatical'): {('antonym', nan),
#               ('derived from', nan),
#               ('related to', nan)},
#              ('agree',
#               'argue'): {('antonym',
#                '[[agree]] is the opposite of [[argue]]')},
#              ('agree',
#               'decline'): {('antonym',
#                '[[agree]] is the opposite of [[decline]]')},
#              ('agree',
#               'disagreement'): {('antonym',
#                '[[agree]] is the opposite of [[disagreement]]')},
#              ('agree', 'disagree'): {('antonym', nan), ('distinct from', nan)},
#              ('agree_with', 'disagree_with'): {('antonym', nan),
#               ('has first subevent',
#                'The first thing you do when you [[agree with someone]] is [[disagree with them]]')},
#              ('agreement',
#               'dispute'): {('antonym',
#                '[[agreement]] is the opposite of [[dispute]]')},
#              ('agromania', 'agrophobia'): {('antonym', nan)},
#              ('ahead', 'behind'): {('antonym', nan)},
#              ("ahead_of_one's_time", "before_one's_time"): {('antonym', nan)},
#              ("ahead_of_one's_time", "behind_one's_time"): {('antonym', nan)},
#              ('ahermatypic', 'hermatypic'): {('antonym', nan),
#               ('derived from', nan)},
#              ('ahle_hadith', 'ahle_quran'): {('antonym', nan)},
#              ('aibohphobia', 'ailihphilia'): {('antonym', nan)},
#              ('ailihphilia', 'aibohphobia'): {('antonym', nan)},
#              ('ailurophile', 'ailurophobe'): {('antonym', nan)},
#              ('ailurophilia', 'ailurophobia'): {('antonym', nan)},
#              ('ailurophilia', 'galeophobia'): {('antonym', nan)},
#              ('ailurophilic', 'ailurophobic'): {('antonym', nan)},
#              ('ailurophobe', 'ailurophile'): {('antonym', nan)},
#              ('ailurophobia', 'ailurophilia'): {('antonym', nan)},
#              ('ailurophobic', 'ailurophilic'): {('antonym', nan)},
#              ('aimful', 'aimless'): {('antonym', nan)},
#              ('aimfully', 'aimlessly'): {('antonym', nan)},
#              ('air',
#               'earth'): {('antonym',
#                '[[air]] is the opposite of [[earth]]'), ('distinct from', '[[air]] is not [[earth]]'), ('related to',
#                nan)},
#              ('air',
#               'fire'): {('antonym',
#                '[[air]] is the opposite of [[fire]]'), ('distinct from', '[[air]] is not [[fire]]')},
#              ('air',
#               'ground'): {('antonym',
#                '[[air]] is the opposite of [[ground]]'), ('related to', nan)},
#              ('air',
#               'land'): {('antonym', '[[air]] is the opposite of [[land]]')},
#              ('air',
#               'vacuum'): {('antonym', '[[air]] is the opposite of [[vacuum]]'),
#               ('distinct from', '[[air]] is not [[vacuum]]'),
#               ('related to', nan)},
#              ('air',
#               'water'): {('antonym',
#                '[[air]] is the opposite of [[water]]'), ('distinct from', '[[air]] is not [[water]]')},
#              ('air',
#               'water_fire'): {('antonym',
#                '[[air]] is the opposite of [[water fire]]')},
#              ('airable', 'unairable'): {('antonym', nan)},
#              ('airside', 'landside'): {('antonym', nan)},
#              ('airtight', 'breathable'): {('antonym', nan)},
#              ('airtight', 'transpirable'): {('antonym', nan)},
#              ('airworthiness', 'unairworthiness'): {('antonym', nan)},
#              ('airworthy', 'unflyable'): {('antonym', nan)},
#              ('aisle', 'window'): {('antonym', nan)},
#              ('aisle_seat', 'window_seat'): {('antonym', nan)},
#              ('alacrity', 'apathy'): {('antonym', nan)},
#              ('alacrity', 'disinclination'): {('antonym', nan)},
#              ('alacrity', 'hesitance'): {('antonym', nan)},
#              ('alacrity', 'indifference'): {('antonym', nan)},
#              ('alacrity', 'reluctance'): {('antonym', nan)},
#              ('albinism', 'melanism'): {('antonym', nan)},
#              ('albino', 'hypermelanistic'): {('antonym', nan)},
#              ('albino', 'hypermelanoid'): {('antonym', nan)},
#              ('albinoism', 'melanism'): {('antonym', nan)},
#              ('alcoholic', 'nonalcoholic'): {('antonym', nan)},
#              ('alcoholic', 'teetotaler'): {('antonym', nan)},
#              ('algebraic', 'transcendental'): {('antonym', nan)},
#              ('alien',
#               'human'): {('antonym',
#                '[[alien]] is the opposite of [[human]]')},
#              ('alienable', 'inalienable'): {('antonym', nan)},
#              ('alienate', 'accept'): {('antonym', nan)},
#              ('alikeness', 'unalikeness'): {('antonym', nan)},
#              ('aliovalent', 'isovalent'): {('antonym', nan)},
#              ('aliphatic', 'aromatic'): {('antonym', nan),
#               ('related to', nan)},
#              ('aliquot', 'aliquant'): {('antonym', nan)},
#              ('alive', 'dead'): {('antonym', nan), ('related to', nan)},
#              ('aliyah', 'yerida'): {('antonym', nan)},
#              ('alkali', 'acid'): {('antonym', nan)},
#              ('alkalify', 'acidify'): {('antonym', nan)},
#              ('alkaline', 'acidic'): {('antonym', nan)},
#              ('alkalinity', 'acidity'): {('antonym', nan)},
#              ('all',
#               'none'): {('antonym', '[[all]] is the opposite of [[none]]'),
#               ('distinct from', '[[all]] is not [[none]]'),
#               ('related to', '[[all]] is related to [[none]]')},
#              ('all',
#               'nothing'): {('antonym',
#                '[[all]] is the opposite of [[nothing]]'), ('distinct from',
#                '[[all]] is not [[nothing]]'), ('related to',
#                '[[all]] is related to [[nothing]]')},
#              ('alleviable', 'unalleviable'): {('antonym', nan)},
#              ('alligator',
#               'crocodile'): {('antonym',
#                '[[alligator]] is the opposite of [[crocodile]]'), ('related to',
#                '[[alligator]] is related to [[crocodile]]')},
#              ('allo', 'auto'): {('antonym', nan)},
#              ('allocate', 'free'): {('antonym', nan)},
#              ('allocentric', 'autocentric'): {('antonym', nan)},
#              ('allocentric', 'egocentric'): {('antonym', nan),
#               ('related to', nan)},
#              ('allocentric', 'idiocentric'): {('antonym', nan)},
#              ('allocentric', 'self_absorbed'): {('antonym', nan)},
#              ('allocentric', 'self_centered'): {('antonym', nan)},
#              ('allocentric', 'selfish'): {('antonym', nan)},
#              ('allocentrism', 'autocentrism'): {('antonym', nan)},
#              ('allochthonous', 'autochthonous'): {('antonym', nan)},
#              ('alloerotic', 'analloerotic'): {('antonym', nan)},
#              ('alloeroticism', 'autoeroticism'): {('antonym', nan)},
#              ('allopoiesis', 'autopoiesis'): {('antonym', nan)},
#              ('allopolyploidy', 'autopolyploidy'): {('antonym', nan)},
#              ('allosexual', 'asexual'): {('antonym', nan),
#               ('related to', nan)},
#              ('allosexual', 'autosexual'): {('antonym', nan)},
#              ('allosexual', 'heterosexual'): {('antonym', nan),
#               ('related to', nan)},
#              ('allosexual', 'isosexual'): {('antonym', nan),
#               ('related to', nan)},
#              ('allospecific', 'conspecific'): {('antonym', nan)},
#              ('allothetic', 'idiothetic'): {('antonym', nan)},
#              ('allow',
#               'deny'): {('antonym',
#                '[[allow]] is the opposite of [[deny]]'), ('distinct from', '[[allow]] is not [[deny]]')},
#              ('allow',
#               'forbid'): {('antonym',
#                '[[allow]] is the opposite of [[forbid]]'), ('related to',
#                '[[allow]] is related to [[forbid]]')},
#              ('allow',
#               'permitted'): {('antonym',
#                '[[allow]] is the opposite of [[permitted]]')},
#              ('allow',
#               'prohibit'): {('antonym',
#                '[[allow]] is the opposite of [[prohibit]]')},
#              ('allow',
#               'reject'): {('antonym',
#                '[[allow]] is the opposite of [[reject]]')},
#              ('allow',
#               'restrict'): {('antonym',
#                '[[allow]] is the opposite of [[restrict]]')},
#              ('allowed', 'forbidden'): {('antonym', nan)},
#              ('allowed', 'prohibited'): {('antonym', nan)},
#              ('ally',
#               'enemy'): {('antonym',
#                '[[ally]] is the opposite of [[enemy]]'), ('distinct from',
#                '[[ally]] is not [[enemy]]')},
#              ('almost',
#               'exact'): {('antonym',
#                '[[almost]] is the opposite of [[exact]]')},
#              ('alogical', 'logical'): {('antonym', nan),
#               ('derived from', nan),
#               ('related to', nan)},
#              ('alone',
#               'crowd'): {('antonym',
#                '[[alone]] is the opposite of [[crowd]]')},
#              ('alone',
#               'crowded'): {('antonym',
#                '[[alone]] is the opposite of [[crowded]]')},
#              ('alone',
#               'in_crowd'): {('antonym',
#                '[[alone]] is the opposite of [[in crowd]]')},
#              ('alone',
#               'many_people'): {('antonym',
#                '[[alone]] is the opposite of [[many people]]')},
#              ('alone',
#               'others'): {('antonym',
#                '[[alone]] is the opposite of [[others]]')},
#              ('alone',
#               'people'): {('antonym',
#                '[[alone]] is the opposite of [[people]]')},
#              ('alone',
#               'someone'): {('antonym',
#                '[[alone]] is the opposite of [[someone]]')},
#              ('alone',
#               'together'): {('antonym',
#                '[[alone]] is the opposite of [[together]]'), ('distinct from',
#                '[[alone]] is not [[together]]')},
#              ('alone',
#               'with'): {('antonym',
#                '[[alone]] is the opposite of [[with]]'), ('distinct from', '[[alone]] is not [[with]]')},
#              ('alone',
#               'with_others'): {('antonym',
#                '[[alone]] is the opposite of [[with others]]')},
#              ('alone',
#               'with_people'): {('antonym',
#                '[[alone]] is the opposite of [[with people]]')},
#              ('alone',
#               'with_someone'): {('antonym',
#                '[[alone]] is the opposite of [[with someone]]')},
# ...
#               'specific_one'): {('antonym',
#                '[[any]] is the opposite of [[specific one]]')},
#              ('apart', 'together'): {('antonym', nan)},
#              ('apartheid', 'antiapartheid'): {('antonym', nan)},
#              ('apartment',
#               'house'): {('antonym',
#                '[[apartment]] is the opposite of [[house]]'), ('related to',
#                '[[apartment]] is related to [[house]]')},
#              ('apastron', 'periastron'): {('antonym', nan)},
#              ('apathy', 'empathy'): {('antonym', nan)},
#              ('apathy', 'sympathy'): {('antonym', nan)},
#              ('apazine', 'genzine'): {('antonym', nan)},
#              ('apex',
#               'bottom'): {('antonym',
#                '[[apex]] is the opposite of [[bottom]]')},
#              ('apex', 'nadir'): {('antonym', nan)},
#              ('aphananthous', 'phaneranthous'): {('antonym', nan)},
#              ('aphelion', 'perihelion'): {('antonym', nan),
#               ('related to', nan)},
#              ('aphesis', 'apocope'): {('antonym', nan)},
#              ('aphesis', 'prothesis'): {('antonym', nan)},
#              ('aphotic', 'photic'): {('antonym', nan), ('derived from', nan)},
#              ('aphrodisiac', 'antaphrodisiac'): {('antonym', nan)},
#              ('apoapsis', 'periapsis'): {('antonym', nan)},
#              ('apocalyptic', 'nonapocalyptic'): {('antonym', nan)},
#              ('apocenter', 'pericenter'): {('antonym', nan)},
#              ('apocentromeric', 'pericentromeric'): {('antonym', nan)},
#              ('apodeictic', 'anapodeictic'): {('antonym', nan)},
#              ('apodictic', 'assertorical'): {('antonym', nan)},
#              ('apodictic', 'problematic'): {('antonym', nan)},
#              ('apodosis', 'protasis'): {('antonym', nan)},
#              ('apogalactic', 'perigalactic'): {('antonym', nan)},
#              ('apogalacticon', 'perigalacticon'): {('antonym', nan)},
#              ('apogee', 'nadir'): {('antonym', nan)},
#              ('apogee', 'periapsis'): {('antonym', nan)},
#              ('apogee', 'perigee'): {('antonym', nan)},
#              ('apoherm', 'periherm'): {('antonym', nan)},
#              ('apollo', 'hermes'): {('antonym', nan)},
#              ('apollonian', 'dionysian'): {('antonym', nan),
#               ('related to', nan)},
#              ('apologetic', 'unapologetic'): {('antonym', nan)},
#              ('apolune', 'perilune'): {('antonym', nan)},
#              ('apomorph', 'pleisiomorph'): {('antonym', nan)},
#              ('apomorphy', 'plesiomorphy'): {('antonym', nan)},
#              ('apophatic', 'cataphatic'): {('antonym', nan)},
#              ('apotemnophilia', 'apotemnophobia'): {('antonym', nan)},
#              ('apotemnophobia', 'acrotomophilia'): {('antonym', nan)},
#              ('apotemnophobia', 'apotemnophilia'): {('antonym', nan)},
#              ('apparent', 'ambiguous'): {('antonym', nan)},
#              ('apparent', 'hidden'): {('antonym', nan)},
#              ('apparent', 'inapparent'): {('antonym', nan)},
#              ('apparent', 'unapparent'): {('antonym', nan)},
#              ('appear',
#               'dissolve'): {('antonym',
#                '[[appear]] is the opposite of [[dissolve]]')},
#              ('appear',
#               'hide'): {('antonym', '[[appear]] is the opposite of [[hide]]')},
#              ('appear',
#               'vanish'): {('antonym',
#                '[[appear]] is the opposite of [[vanish]]'),
#               ('distinct from', '[[appear]] is not [[vanish]]'),
#               ('related to', '[[appear]] is related to [[vanish]]')},
#              ('appear',
#               'vanishing'): {('antonym',
#                '[[appear]] is the opposite of [[vanishing]]'), ('distinct from',
#                '[[appear]] is not [[vanishing]]')},
#              ('appear', 'disappear'): {('antonym', nan)},
#              ('appearance', 'disappearance'): {('antonym', nan)},
#              ('appearances_are_deceptive',
#               'fine_feathers_make_fine_birds'): {('antonym', nan)},
#              ('appeasable', 'inappeasable'): {('antonym', nan)},
#              ('appease', 'antagonize'): {('antonym', nan)},
#              ('appertain', 'irrelevant'): {('antonym', nan)},
#              ('apple',
#               'banana'): {('antonym',
#                '[[apple]] is the opposite of [[banana]]'),
#               ('distinct from', '[[apple]] is not [[banana]]'),
#               ('located near', '[[an apple]] is typically near [[a banana]]')},
#              ('apple',
#               'orange'): {('antonym',
#                '[[apple]] is the opposite of [[orange]]'), ('distinct from',
#                '[[apple]] is not [[orange]]'), ('related to',
#                '[[apple]] is related to [[orange]]')},
#              ('apple',
#               'oranges'): {('antonym',
#                '[[apple]] is the opposite of [[oranges]]'), ('distinct from',
#                '[[apple]] is not [[oranges]]'), ('related to',
#                '[[apple]] is related to [[oranges]]')},
#              ('apple',
#               'pear'): {('antonym',
#                '[[apple]] is the opposite of [[pear]]'), ('distinct from', '[[apple]] is not [[pear]]'), ('related to',
#                '[[apple]] is related to [[pear]]')},
#              ('apple',
#               'pears'): {('antonym',
#                '[[apple]] is the opposite of [[pears]]'), ('related to',
#                '[[apple]] is related to [[pears]]')},
#              ('apples_and_oranges', 'apples_to_apples'): {('antonym', nan)},
#              ('apples_and_oranges',
#               'apples_to_apples_oranges_to_oranges'): {('antonym', nan)},
#              ('apples_and_oranges',
#               'oranges_with_oranges'): {('antonym', nan)},
#              ('applicability', 'inapplicability'): {('antonym', nan)},
#              ('applicable', 'inapplicable'): {('antonym', nan)},
#              ('applied', 'pure'): {('antonym', nan)},
#              ('applied_mathematics', 'pure_mathematics'): {('antonym', nan),
#               ('related to', nan)},
#              ('apply',
#               'give'): {('antonym',
#                '[[apply]] is the opposite of [[give]]'), ('manner of', '[[apply]] is a way to [[give]]'), ('related to',
#                '[[apply]] is related to [[give]]'), ('synonym',
#                '[[apply]] is a synonym of [[give]]')},
#              ('apply',
#               'give_up'): {('antonym',
#                '[[apply]] is the opposite of [[give up]]')},
#              ('apply',
#               'quit'): {('antonym', '[[apply]] is the opposite of [[quit]]')},
#              ('apply',
#               'up'): {('antonym', '[[apply]] is the opposite of [[up]]')},
#              ('appointive', 'elective'): {('antonym', nan)},
#              ('appointment', 'dismissal'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('apportion', 'amass'): {('antonym', nan)},
#              ('apposite', 'inapposite'): {('antonym', nan)},
#              ('appreciation', 'depreciation'): {('antonym', nan)},
#              ('apprecihate', 'appreciate'): {('antonym', nan),
#               ('derived from', nan)},
#              ('apprehendable', 'unapprehendable'): {('antonym', nan)},
#              ('apprehension', 'inapprehension'): {('antonym', nan)},
#              ('apprehension', 'misapprehension'): {('antonym', nan)},
#              ('approbation', 'disapprobation'): {('antonym', nan)},
#              ('approbation', 'reprobation'): {('antonym', nan)},
#              ('approbative', 'pejorative'): {('antonym', nan),
#               ('related to', nan)},
#              ('approbative', 'reprobative'): {('antonym', nan)},
#              ('appropriate', 'inappropriate'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('appropriately', 'inappropriately'): {('antonym', nan)},
#              ('approval', 'disapproval'): {('antonym', nan)},
#              ('approve', 'disapprove'): {('antonym', nan),
#               ('distinct from', nan)},
#              ('approximate', 'exact'): {('antonym', nan), ('related to', nan)},
#              ('approximately', 'accurately'): {('antonym', nan)},
#              ('approximately', 'definitely'): {('antonym', nan)},
#              ('approximately', 'exactly'): {('antonym', nan)},
#              ('approximately', 'precisely'): {('antonym', nan)},
#              ('apropos', 'malapropos'): {('antonym', nan)},
#              ('aprotic', 'protic'): {('antonym', nan), ('derived from', nan)},
#              ('apteral', 'peripteral'): {('antonym', nan)},
#              ('apterium', 'pteryla'): {('antonym', nan)},
#              ('aptitude', 'inaptitude'): {('antonym', nan)},
#              ('apéritif', 'digestif'): {('antonym', nan)},
#              ('aquarius', 'leo'): {('antonym', nan)},
#              ('araucarian', 'ximenean'): {('antonym', nan)},
#              ('arcane', 'mundane'): {('antonym', nan)},
#              ('archegonium', 'antheridium'): {('antonym', nan),
#               ('similar to', nan)},
#              ('archimedean_ordered_field',
#               'non_archimedean_ordered_field'): {('antonym', nan)},
#              ('archist', 'anarchist'): {('antonym', nan)},
#              ('archiver', 'unarchiver'): {('antonym', nan)},
#              ('ardor', 'apathy'): {('antonym', nan)},
#              ('areligious', 'religious'): {('antonym', nan),
#               ('derived from', nan),
#               ('distinct from', nan),
#               ('related to', nan)},
#              ("aren't", 'am'): {('antonym', nan)},
#              ("aren't", 'are'): {('antonym', nan),
#               ('derived from', nan),
#               ('related to', nan)},
#              ('argumentum_ad_crumenam',
#               'argumentum_ad_lazarum'): {('antonym', nan)},
#              ('argumentum_ad_lazarum',
#               'argumentum_ad_crumenam'): {('antonym', nan)},
#              ('aries', 'libra'): {('antonym', nan)},
#              ('arise',
#               'abed'): {('antonym', '[[arise]] is the opposite of [[abed]]')},
#              ('arise',
#               'descend'): {('antonym',
#                '[[arise]] is the opposite of [[descend]]')},
#              ('arise',
#               'down'): {('antonym', '[[arise]] is the opposite of [[down]]')},
#              ('arise',
#               'fall'): {('antonym', '[[arise]] is the opposite of [[fall]]')},
#              ('arise',
#               'fall_down'): {('antonym',
#                '[[arise]] is the opposite of [[fall down]]')},
#              ('arise',
#               'get_down'): {('antonym',
#                '[[arise]] is the opposite of [[get down]]')},
#              ('arise',
#               'go'): {('antonym',
#                '[[arise]] is the opposite of [[go]]'), ('related to', '[[arise]] is related to [[go]]')},
#              ('arise',
#               'go_down'): {('antonym',
#                '[[arise]] is the opposite of [[go down]]')},
#              ('arise',
#               'lay'): {('antonym', '[[arise]] is the opposite of [[lay]]')},
#              ('arise',
#               'lay_down'): {('antonym',
#                '[[arise]] is the opposite of [[lay down]]')},
#              ('arise',
#               'lie'): {('antonym', '[[arise]] is the opposite of [[lie]]')},
#              ('arise',
#               'lie_down'): {('antonym',
#                '[[arise]] is the opposite of [[lie down]]')},
#              ('arise',
#               'lower'): {('antonym',
#                '[[arise]] is the opposite of [[lower]]')},
#              ('arise',
#               'repose'): {('antonym',
#                '[[arise]] is the opposite of [[repose]]')},
#              ('arise',
#               'set'): {('antonym', '[[arise]] is the opposite of [[set]]')},
#              ('arise',
#               'sit'): {('antonym', '[[arise]] is the opposite of [[sit]]')},
#              ('arise',
#               'sit_down'): {('antonym',
#                '[[arise]] is the opposite of [[sit down]]')},
#              ('arise',
#               'sitting'): {('antonym',
#                '[[arise]] is the opposite of [[sitting]]')},
#              ('arise',
#               'sitting_down'): {('antonym',
#                '[[arise]] is the opposite of [[sitting down]]')},
#              ('arise',
#               'sleep'): {('antonym',
#                '[[arise]] is the opposite of [[sleep]]')},
#              ('arise',
#               'sleeping'): {('antonym',
#                '[[arise]] is the opposite of [[sleeping]]')},
#              ('aristocrat', 'plebeian'): {('antonym', nan)},
#              ('arm',
#               'leg'): {('antonym',
#                '[[arm]] is the opposite of [[leg]]'), ('distinct from', '[[arm]] is not [[leg]]'), ('related to',
#                '[[arm]] is related to [[leg]]')},
#              ('armenophile', 'armenophobe'): {('antonym', nan)},
#              ('armenophilia', 'armenophobia'): {('antonym', nan)},
#              ('armenophobe', 'armenophile'): {('antonym', nan)},
#              ('armenophobia', 'armenophilia'): {('antonym', nan)},
#              ('armor',
#               'clothing'): {('antonym',
#                '[[armor]] is the opposite of [[clothing]]'), ('related to',
#                '[[armor]] is related to [[clothing]]')},
#              ('armored', 'nonarmored'): {('antonym', nan)},
#              ('army',
#               'navy'): {('antonym',
#                '[[army]] is the opposite of [[navy]]'), ('distinct from', '[[army]] is not [[navy]]'), ('related to',
#                '[[army]] is related to [[navy]]')},
#              ('aroma', 'odor'): {('antonym', nan)},
#              ('aromatic', 'aliphatic'): {('antonym', nan)},
#              ('around',
#               'far'): {('antonym', '[[around]] is the opposite of [[far]]')},
#              ('around',
#               'here'): {('antonym', '[[around]] is the opposite of [[here]]')},
#              ('around',
#               'within'): {('antonym',
#                '[[around]] is the opposite of [[within]]')},
#              ('around_wicket', 'over_wicket'): {('antonym', nan)},
#              ('arranged_marriage', 'love_match'): {('antonym', nan)},
#              ('arrangement',
#               'disarray'): {('antonym',
#                '[[arrangement]] is the opposite of [[disarray]]')},
#              ('array', 'disarray'): {('antonym', nan)},
#              ('arrhenogeny', 'thelygeny'): {('antonym', nan)},
#              ('arrhizotonic', 'rhizotonic'): {('antonym', nan),
#               ('derived from', nan)},
#              ('arrival',
#               'depart'): {('antonym',
#                '[[arrival]] is the opposite of [[depart]]')},
#              ('arrival',
#               'departure'): {('antonym',
#                '[[arrival]] is the opposite of [[departure]]'), ('antonym',
#                nan), ('distinct from',
#                '[[arrival]] is not [[departure]]'), ('related to', '[[arrival]] is related to [[departure]]')},
#              ('arrival',
#               'leaving'): {('antonym',
#                '[[arrival]] is the opposite of [[leaving]]')},
#              ('arrive',
#               'depart'): {('antonym',
#                '[[arrive]] is the opposite of [[depart]]'), ('antonym',
#                nan), ('distinct from', '[[arrive]] is not [[depart]]'), ('related to',
#                '[[arrive]] is related to [[depart]]')},
#              ('arrive',
#               'departure'): {('antonym',
#                '[[arrive]] is the opposite of [[departure]]'), ('related to',
#                '[[arrive]] is related to [[departure]]')},
#              ('arrive',
#               'disembark'): {('antonym',
#                '[[arrive]] is the opposite of [[disembark]]')},
#              ('arrive',
#               'leave'): {('antonym',
#                '[[arrive]] is the opposite of [[leave]]'), ('distinct from',
#                '[[arrive]] is not [[leave]]')},
#              ('arrogance', 'servility'): {('antonym', nan)},
#              ('arrogant', 'humble'): {('antonym', nan)},
#              ('arrogant', 'modest'): {('antonym', nan)},
#              ('arrogant', 'servile'): {('antonym', nan)},
#              ('arrogate', 'abandon'): {('antonym', nan)},
#              ('arrogate', 'abdicate'): {('antonym', nan)},
#              ('arrogate', 'relinquish'): {('antonym', nan)},
#              ('arrogate', 'renounce'): {('antonym', nan)},
#              ...})

# %%
get_relations_between_words('stepfather', 'father')
# Out:
# [{'edge': ('stepfather', 'DerivedFrom', 'father'), 'example': None},
#  {'edge': ('stepfather', 'IsA', 'father'), 'example': None},
#  {'edge': ('stepfather', 'DerivedFrom', 'father'), 'example': None}]

# %%
get_relations_between_words('bank', 'chase')
# Out:
# [{'edge': ('chase', 'IsA', 'bank'), 'example': None}]

# %%
get_relations_between_words('bank', 'bank of china')
# Out:
# [{'edge': ('bank of china', 'IsA', 'bank'), 'example': None}]

# %%
get_relations_between_words('bank', 'teller')
# Out:
# [{'edge': ('teller', 'RelatedTo', 'bank'), 'example': None},
#  {'edge': ('bank', 'RelatedTo', 'teller'),
#   'example': '[[bank]] is related to [[teller]]'}]
